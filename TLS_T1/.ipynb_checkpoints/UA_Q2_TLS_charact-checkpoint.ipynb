# %% [markdown]
# # TLS Characterization of UA Q2
# ### using Experiment and Analysis classes

# %%
from qm.qua import *
from qm import QuantumMachinesManager, SimulationConfig, LoopbackInterface, generate_qua_script
from qm.octave import *
from qm.octave.octave_manager import ClockMode
from configuration import *
from scipy import signal
from qualang_tools.bakery import baking
from qualang_tools.units import unit
from qm.octave import QmOctaveConfig
from set_octave import ElementsSettings, octave_settings
from quam import QuAM
from scipy.io import savemat, loadmat
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter
from qutip import *
from typing import Union
from macros import *
import datetime 
import os
import time
import warnings
import json
import matplotlib.pyplot as plt
import numpy as np
import Labber

from ExperimentClass import ExperimentHandle
from AnalysisClass import AnalysisHandle

warnings.filterwarnings("ignore")

qubit_index = 1 # for UA Q2
res_index = 1 # for UA Q2
flux_index = 1 # for UA Q2
TLS_index = 0
# Out:
# 2024-05-01 16:56:07,504 - qm - INFO     - Starting session: 6db0b622-4a1e-4966-9d3c-978beea4bee4

# %%
Experiment = ExperimentHandle()
Analysis = AnalysisHandle()
machine = Analysis.get_machine()

# %%
# initialize Labber-controlled hardware
Experiment.set_Labber(Analysis.get_machine(), qubit_index, res_index, flux_index)
# set octave to external clock
#Experiment.set_external_clock()

# %%
# this updates the octave settings, including rf_gain and rf_output_mode
Experiment.octave_calibration(qubit_index,res_index,flux_index,calibration_flag = False)
# Out:
# 2024-05-01 09:41:22,397 - qm - INFO     - Octave "octave1" Health check passed, current temperature 57
# INFO:qm:Octave "octave1" Health check passed, current temperature 57
# 2024-05-01 09:41:22,401 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-05-01 09:41:22,420 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed

# %%
# change gain RF line for qubit
machine.qubits[qubit_index].rf_gain = 0
machine = Analysis.set_machine(machine)

# %% [markdown]
# # TLS experiments

# %% [markdown]
# ## Set TLS index

# %%
TLS_index = 1

# %% [markdown]
# ## TLS T1

# %%
# set to qubit freq
machine.qubits[qubit_index].f_01 = machine.qubits[qubit_index].f_tls[0] + 0E6
machine.qubits[qubit_index].lo = machine.qubits[qubit_index].f_01 + 50E6
machine = Analysis.set_machine(machine)

# %%
# calibrate octave
Experiment.octave_calibration(qubit_index,res_index,flux_index,machine=machine,calibration_flag = True)
# Out:
# 2024-05-01 09:41:31,530 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-05-01 09:41:31,538 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates r1 for (LO, IF) = (7.184 GHz, -50.000 MHz)
# 2024-05-01 09:41:40,139 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# ------------------------------------- Calibrates q1 for (LO, IF) = (6.248 GHz, -50.000 MHz)
# 2024-05-01 09:41:54,481 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program

# %%
machine.resonators[res_index].rotation_angle += np.pi

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(0.5E3,5000E3+1,100E3)
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.T1.TLS_T1(tau_sweep_abs, qubit_index, res_index, flux_index, TLS_index,
                   n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 5000E3, simulate_flag = False, simulation_len = 15_000, 
                   plot_flag = True, machine = machine)
# Out:
# Execution stopped by user!#                                  ] 32.4% (n=3244/10000.0) --> elapsed time: 1214.59s
# Progress: [################                                  ] 32.4% (n=3244/10000.0) --> elapsed time: 1214.78s

# %%
# %matplotlib inline
TLS_T1 = Analysis.exp1D.T1(tau_sweep_abs,sig_amp,method = "exp")
# Out:
# Qubit T1 [us]: 375.8983819770389

# %% [markdown]
# # TLS drive

# %% [markdown]
# ## TLS spectroscopy

# %% [markdown]
# ### This cell is only for the first run, to estimate TLS freq

# %%
TLS_index = 1

# %%
# TLS freq estimate based on SWAP flux amplitude
TLS_freq_est = np.polyval(machine.qubits[qubit_index].AC_tuning_curve,machine.flux_lines[flux_index].iswap.level[TLS_index])
TLS_freq_est = np.round(TLS_freq_est * 1E6)
if len(machine.qubits[qubit_index].f_tls) < TLS_index + 2: # need to increase size
    machine.qubits[qubit_index].f_tls.append(int(TLS_freq_est.item()) + 0E6)
    machine.qubits[qubit_index].lo = int(TLS_freq_est.item()) - 200E6
else: # just update the value
    machine.qubits[qubit_index].f_tls[TLS_index+1] = (int(TLS_freq_est.item()))
    machine.qubits[qubit_index].lo = int(TLS_freq_est.item()) - 200E6
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### This is when we already have calibrated TLS freq saved somewhere

# %%
# set the "qubit frequency"
machine.qubits[qubit_index].f_01 = machine.qubits[qubit_index].f_tls[TLS_index] + 0E6
machine.qubits[qubit_index].lo = machine.qubits[qubit_index].f_01 - 200E6
machine = Analysis.set_machine(machine)

# %%
# calibrate octave for TLS sweep
Experiment.octave_calibration(qubit_index,res_index,flux_index,machine = machine,calibration_flag = True)
# Out:
# 2024-05-02 10:40:19,351 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-05-02 10:40:19,361 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates r1 for (LO, IF) = (7.183 GHz, -50.000 MHz)
# 2024-05-02 10:40:27,503 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# ------------------------------------- Calibrates q1 for (LO, IF) = (5.203 GHz, 200.000 MHz)
# 2024-05-02 10:40:41,030 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program

# %%
# %matplotlib qt
TLS_freq_sweep = machine.qubits[qubit_index].f_01 + np.arange(-10E6,10E6+1,0.2E6)
machine, TLS_freq_sweep, sig_amp = Experiment.exp1D.Rabi.TLS_freq(TLS_freq_sweep, qubit_index, res_index, flux_index, TLS_index,
                  n_avg = 1E3, cd_time_qubit = 20E3, cd_time_TLS = 2000E3, simulate_flag = False, simulation_len = 10_000, plot_flag = True, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=1000/1000.0) --> elapsed time: 203.85s
# Progress: [##################################################] 100.0% (n=1000/1000.0) --> elapsed time: 203.94s

# %%
# %matplotlib inline
qubit_freq = Analysis.exp1D.peak_fit(x=TLS_freq_sweep,y=-sig_amp,method="gaussian")
qubit_freq = int(qubit_freq.tolist())
# update TLS freq
machine.qubits[qubit_index].f_tls[TLS_index] = qubit_freq + 0E6
# set the "qubit frequency"
machine.qubits[qubit_index].f_01 = qubit_freq + 0E6
machine.qubits[qubit_index].lo = qubit_freq - 200E6
# save the parameters
machine = Analysis.set_machine(machine)
# Out:
# resonant frequency: 5403.430 MHz

# %% [markdown]
# ## TLS rabi

# %%
machine.flux_lines[flux_index].iswap.level[TLS_index] = 0.219
machine = Analysis.set_machine(machine)

# %%
machine.qubits[qubit_index].pi_amp_tls.append(0.5)
machine = Analysis.set_machine(machine)

# %%
# %matplotlib qt
rabi_duration_sweep = np.arange(4, 200 + 0.1, 5)  # in units of clock cyles
machine, rabi_duration_sweep, sig_amp = Experiment.exp1D.Rabi.TLS_rabi_length(rabi_duration_sweep, qubit_index, res_index, flux_index, TLS_index,
                  n_avg = 1E3, cd_time_qubit = 20E3, cd_time_TLS = 2000E3, simulate_flag = False, simulation_len = 10_000, plot_flag = True, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=1000/1000.0) --> elapsed time: 80.71s

# %%
# %matplotlib inline
pi_pulse_length = Analysis.exp1D.rabi_length(rabi_duration_sweep,-sig_amp,method = "decaying_time_rabi", plot_flag = True)
# Out:
# T2rabi: 4110.2 ns
# rabi_pi_pulse: 316.0 ns
# half period: 317.07 ns

# %%
pi_length = 316
if len(machine.qubits[qubit_index].pi_length_tls) < TLS_index + 1: # need to increase size
    machine.qubits[qubit_index].pi_length_tls.append(pi_length)
else: # just update the value
    machine.qubits[qubit_index].pi_length_tls[TLS_index] = pi_length    
machine.qubits[qubit_index].pi_length_tls[0] = pi_length
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## TLS Power Rabi

# %%
# %matplotlib qt
rabi_amp_sweep_rel = np.arange(0, 1.5, 0.05) 
machine, rabi_amp_sweep_abs, sig_amp = Experiment.exp1D.Rabi.TLS_rabi_amp(rabi_amp_sweep_rel, qubit_index, res_index, flux_index, TLS_index = TLS_index,  
                                          n_avg = 4E3, cd_time_qubit = 20E3, cd_time_TLS = 2000E3, plot_flag = False, machine = machine)
# Out:
# some abs amps > 0.5, removed from experiment run
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 161.52s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 161.57s

# %%
# %matplotlib inline
pi_pulse_amp = Analysis.exp1D.rabi_length(rabi_amp_sweep_abs,sig_amp,method = "power_rabi", plot_flag = True)
# Out:
# rabi_pi_pulse_amp: 0.56014 V
# half period: 0.5101349 V

# %%
if len(machine.qubits[qubit_index].pi_length_tls) < TLS_index + 1: # need to increase size
    machine.qubits[qubit_index].pi_amp_tls.append(pi_pulse_amp)
else: # just update the value
    machine.qubits[qubit_index].pi_amp_tls[TLS_index] = pi_pulse_amp
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## TLS Ramsey

# %%
# %matplotlib qt
ramsey_duration_sweep = np.arange(4, 700 + 0.1, 2)  # in units of clock cyles
machine, ramsey_duration_sweep, sig_I = Experiment.exp1D.Ramsey.TLS_ramsey(ramsey_duration_sweep, qubit_index, res_index, flux_index, TLS_index,
          n_avg = 5E3, detuning = 5E6, cd_time_qubit = 20E3, cd_time_TLS = 2000E3, plot_flag = True, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Execution stopped by user!                                   ] 30.9% (n=1544/5000.0) --> elapsed time: 1089.25s
# Progress: [###############                                   ] 30.9% (n=1544/5000.0) --> elapsed time: 1089.68s

# %%
# %matplotlib inline
q_T2star = Analysis.exp1D.ramsey(ramsey_duration_sweep, sig_I,plot_flag = True)
# Out:
# Qubit T2* [ns]: 1105.2131241403074
# Detuning [MHz]: 4.696361106202968
# Exponent n: 1.6271427710172157

# %% [markdown]
# ## TLS T1 with direct driving

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(1E3,5000E3+1,100E3)
machine, tau_sweep_abs, sig_I = Experiment.exp1D.T1.TLS_T1_driving(tau_sweep_abs, qubit_index, res_index, flux_index, TLS_index,
                   n_avg = 2E3, cd_time_qubit = 20E3, cd_time_TLS = 5000E3, simulate_flag = False, simulation_len = 15_000, plot_flag = True)
# Out:
# Execution stopped by user!                                   ] 4.0% (n=81/2000.0) --> elapsed time: 30.05s
# Progress: [##                                                ] 4.1% (n=82/2000.0) --> elapsed time: 30.32s

# %%
# %matplotlib inline
TLS_T1 = Analysis.exp1D.T1(tau_sweep_abs,sig_I,method = "exp")
# Out:
# Qubit T1 [us]: 1232.2871127535398

# %% [markdown]
# # TLS Dynamical Decoupling

# %% [markdown]
# ## TLS echo

# %%
# %matplotlib qt
tau_sweep = np.arange(4, 4E3 + 0.1, 10)  # in units of clock cyles
machine, tau_sweep_abs, sig_I = Experiment.exp1D.DD.TLS_echo(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          n_avg = 2E3, cd_time_qubit = 20E3, cd_time_TLS = 5000E3, plot_flag = True, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=2000/2000.0) --> elapsed time: 4027.64s
# Progress: [##################################################] 100.0% (n=2000/2000.0) --> elapsed time: 4027.76s

# %%
# %matplotlib inline
TLS_T2e = Analysis.exp1D.T1(tau_sweep_abs*2,sig_I,method = "exp")
# Out:
# Qubit T1 [us]: 15.864102927942238

# %% [markdown]
# ## TLS CPMG2

# %%
# %matplotlib qt
tau_sweep = np.arange(4, 1000 + 0.1, 4)  # in units of clock cyles
machine, tau_sweep_abs, sig_I = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 2, n_avg = 2E3, cd_time_qubit = 20E3, cd_time_TLS = 2000E3, plot_flag = True, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Execution stopped by user!                                   ] 24.4% (n=488/2000.0) --> elapsed time: 247.31s
# Progress: [############                                      ] 24.4% (n=488/2000.0) --> elapsed time: 247.50s

# %% [markdown]
# ## TLS CPMG4

# %%
# %matplotlib qt
tau_sweep = np.arange(4, 2000 + 0.1, 1)  # in units of clock cyles
machine, tau_sweep_abs, sig_I = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 4, n_avg = 2E3, cd_time_qubit = 20E3, cd_time_TLS = 5000E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=2000/2000.0) --> elapsed time: 20176.58s

# %% [markdown]
# ## TLS CPMG6

# %%
# %matplotlib qt
tau_sweep = np.arange(4, 300 + 0.1, 1)  # in units of clock cyles
machine, tau_sweep_abs, sig_I = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 6, n_avg = 2E3, cd_time_qubit = 20E3, cd_time_TLS = 2000E3, plot_flag = True, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=2000/2000.0) --> elapsed time: 1205.31s
# Progress: [##################################################] 100.0% (n=2000/2000.0) --> elapsed time: 1205.44s
# Execution stopped by user!

# %% [markdown]
# ## TLS CPMG8

# %%
# %matplotlib qt
tau_sweep = np.arange(4, 300 + 0.1, 1)  # in units of clock cyles
machine, tau_sweep_abs, sig_I = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 8, n_avg = 2E3, cd_time_qubit = 20E3, cd_time_TLS = 5000E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [                                                  ] 0.2% (n=5/2000.0) --> elapsed time: 6.84s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 3
#       1 get_ipython().run_line_magic('matplotlib', 'qt')
#       2 tau_sweep = np.arange(4, 300 + 0.1, 1)  # in units of clock cyles
# ----> 3 machine, tau_sweep_abs, sig_I = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
#       4           N_CPMG = 8, n_avg = 2E3, cd_time_qubit = 20E3, cd_time_TLS = 5000E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
#
# File ~\QM\QM_UALA\TLS_T1\ExperimentClass_1D.py:4417, in EH_DD.TLS_CPMG(self, tau_sweep, qubit_index, res_index, flux_index, TLS_index, if_x_pi2, N_CPMG, n_avg, minus_pulse, cd_time_qubit, cd_time_TLS, tPath, f_str_datetime, simulate_flag, simulation_len, plot_flag, machine)
#    4413 	interrupt_on_close(fig, job)  # Interrupts the job when closing the figure
#    4415 while results.is_processing():
#    4416 	# Fetch results
# -> 4417 	I, Q, iteration = results.fetch_all()
#    4418 	I = u.demod2volts(I, machine.resonators[qubit_index].readout_pulse_length)
#    4419 	Q = u.demod2volts(Q, machine.resonators[qubit_index].readout_pulse_length)
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\qualang_tools\results\results.py:95, in fetching_tool.fetch_all(self)
#      93     self.results = []
#      94     for i in range(len(self.data_handles)):
# ---> 95         self.results.append(self._format(self.data_handles[i].fetch_all()))
#      96 return self.results
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\qm\results\single_streaming_result_fetcher.py:39, in SingleStreamingResultFetcher.fetch_all(self, check_for_errors, flat_struct)
#      24 def fetch_all(
#      25     self, *, check_for_errors: bool = False, flat_struct: bool = False
#      26 ) -> Optional[numpy.typing.NDArray[numpy.generic]]:
#      27     """Fetch a result from the current result stream saved in server memory.
#      28     The result stream is populated by the save() and save_all() statements.
#      29     Note that if save_all() statements are used, calling this function twice
#    (...)
#      37         all result of current result stream
#      38     """
# ---> 39     return self.fetch(0, flat_struct=flat_struct, check_for_errors=check_for_errors)
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\qm\results\single_streaming_result_fetcher.py:67, in SingleStreamingResultFetcher.fetch(self, item, check_for_errors, flat_struct)
#      65 if (isinstance(item, int) and item != 0) or isinstance(item, slice):
#      66     logger.warning("Fetching single result will always return the single value")
# ---> 67 value = self.strict_fetch(0, check_for_errors=check_for_errors, flat_struct=flat_struct)
#      68 if flat_struct:
#      69     if len(value) == 0:
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\qm\results\base_streaming_result_fetcher.py:380, in BaseStreamingResultFetcher.strict_fetch(self, item, check_for_errors, flat_struct)
#     377 if step != 1 and step is not None:
#     378     raise Exception("fetch supports step=1 or None in slices")
# --> 380 header = self._get_named_header(check_for_errors=check_for_errors, flat_struct=flat_struct)
#     382 if stop is None:
#     383     stop = header.count_so_far
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\qm\results\base_streaming_result_fetcher.py:289, in BaseStreamingResultFetcher._get_named_header(self, check_for_errors, flat_struct)
#     288 def _get_named_header(self, check_for_errors: bool = False, flat_struct: bool = False) -> NamedJobResultHeader:
# --> 289     response = self._service.get_named_header(self._job_id, self.name, flat_struct)
#     290     dtype = _parse_dtype(response.simple_d_type)
#     292     if check_for_errors and response.has_execution_errors:
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\qm\api\base_api.py:27, in connection_error_handle_decorator.<locals>.wrapped(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def wrapped(*args: P.args, **kwargs: P.kwargs) -> Ret:
#      26     try:
# ---> 27         return func(*args, **kwargs)
#      28     except grpclib.exceptions.GRPCError as e:
#      29         logger.exception("Encountered connection error from QOP")
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\qm\api\job_result_api.py:52, in JobResultServiceApi.get_named_header(self, job_id, output_name, flat_struct)
#      50 def get_named_header(self, job_id: str, output_name: str, flat_struct: bool) -> GetJobNamedResultHeaderResponse:
#      51     request = GetJobNamedResultHeaderRequest(job_id=job_id, output_name=output_name, flat_format=flat_struct)
# ---> 52     response = run_async(self._stub.get_job_named_result_header(request, timeout=self._timeout))
#      53     return response
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\qm\utils\async_utils.py:37, in run_async(coroutine)
#      36 def run_async(coroutine: Coroutine[Any, Any, T]) -> T:
# ---> 37     return create_future(coroutine).result()
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\qm\utils\async_utils.py:33, in create_future(coroutine)
#      32 def create_future(coroutine: Coroutine[Any, Any, T]) -> asyncio.Future:  # type: ignore[type-arg]
# ---> 33     return asyncio.run_coroutine_threadsafe(coroutine, loop=EventLoopThread().loop)
#
# File ~\.conda\envs\labber-qm-env\lib\asyncio\tasks.py:930, in run_coroutine_threadsafe(coro, loop)
#     927             future.set_exception(exc)
#     928         raise
# --> 930 loop.call_soon_threadsafe(callback)
#     931 return future
#
# File ~\.conda\envs\labber-qm-env\lib\asyncio\base_events.py:770, in BaseEventLoop.call_soon_threadsafe(self, callback, context, *args)
#     768 if handle._source_traceback:
#     769     del handle._source_traceback[-1]
# --> 770 self._write_to_self()
#     771 return handle
#
# File ~\.conda\envs\labber-qm-env\lib\asyncio\selector_events.py:140, in BaseSelectorEventLoop._write_to_self(self)
#     137     return
#     139 try:
# --> 140     csock.send(b'\0')
#     141 except OSError:
#     142     if self._debug:
#
# KeyboardInterrupt:

# %% [markdown]
# ## TLS CPMG12

# %%
# %matplotlib qt
tau_sweep = np.arange(4, 2000 + 0.1, 1)  # in units of clock cyles
machine, tau_sweep_abs, sig_I = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 12, n_avg = 2E3, cd_time_qubit = 20E3, cd_time_TLS = 5000E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=2000/2000.0) --> elapsed time: 20440.29s
# Progress: [##################################################] 100.0% (n=2000/2000.0) --> elapsed time: 20440.33s

# %% [markdown]
# ## TLS CPMG16

# %%
# %matplotlib qt
tau_sweep = np.arange(4, 2000 + 0.1, 1)  # in units of clock cyles
machine, tau_sweep_abs, sig_I = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 16, n_avg = 2E3, cd_time_qubit = 20E3, cd_time_TLS = 5000E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=2000/2000.0) --> elapsed time: 20573.02s
# Progress: [##################################################] 100.0% (n=2000/2000.0) --> elapsed time: 20573.07s

# %% [markdown]
# ## TLS CPMG20

# %%
# %matplotlib qt
tau_sweep = np.arange(4, 800 + 0.1, 1)  # in units of clock cyles
machine, tau_sweep_abs, sig_I = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 20, n_avg = 4E3, cd_time_qubit = 20E3, cd_time_TLS = 400E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)

# %% [markdown]
# ## TLS CPMG24

# %%
# %matplotlib qt
tau_sweep = np.arange(4, 800 + 0.1, 1)  # in units of clock cyles
machine, tau_sweep_abs, sig_I = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 24, n_avg = 4E3, cd_time_qubit = 20E3, cd_time_TLS = 400E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)

# %% [markdown]
# ## TLS CPMG28

# %%
# %matplotlib qt
tau_sweep = np.arange(4, 800 + 0.1, 1)  # in units of clock cyles
machine, tau_sweep_abs, sig_I = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 28, n_avg = 4E3, cd_time_qubit = 20E3, cd_time_TLS = 400E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)

# %% [markdown]
# ## TLS CPMG32

# %%
# %matplotlib qt
tau_sweep = np.arange(4, 800 + 0.1, 1)  # in units of clock cyles
machine, tau_sweep_abs, sig_I = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 32, n_avg = 4E3, cd_time_qubit = 20E3, cd_time_TLS = 400E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
