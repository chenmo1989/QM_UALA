# %% [markdown]
# # TLS Characterization of UA Q3
# ### using Experiment and Analysis classes

# %%
from qm.qua import *
from qm import QuantumMachinesManager, SimulationConfig, LoopbackInterface, generate_qua_script
from qm.octave import *
from qm.octave.octave_manager import ClockMode
from configuration import *
from scipy import signal
from qualang_tools.bakery import baking
from qualang_tools.units import unit
from qm.octave import QmOctaveConfig
from set_octave import ElementsSettings, octave_settings
from quam import QuAM
from scipy.io import savemat, loadmat
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter
from qutip import *
from typing import Union
from macros import *
import datetime 
import os
import time
import warnings
import json
import matplotlib.pyplot as plt
import numpy as np
import Labber

from ExperimentClass import ExperimentHandle
from AnalysisClass import AnalysisHandle

warnings.filterwarnings("ignore")

qubit_index = 2 # for UA Q3
res_index = 2 # for UA Q3
flux_index = 2 # for UA Q3
TLS_index = 0
# Out:
# 2024-04-17 09:19:00,092 - qm - INFO     - Starting session: 9cbd53eb-924e-4ac8-8ecc-12c1b34d8606

# %%
Experiment = ExperimentHandle()
Analysis = AnalysisHandle()
machine = Analysis.get_machine()

# %%
# initialize Labber-controlled hardware
Experiment.set_Labber(Analysis.get_machine(), qubit_index, res_index, flux_index)
# set octave to external clock
#Experiment.set_external_clock()

# %%
# set to sweet spot
machine = Experiment.set_QDAC(qubit_index,res_index,flux_index,machine.flux_lines[flux_index].max_frequency_point)

# %%
# this updates the octave settings, including rf_gain and rf_output_mode
Experiment.octave_calibration(qubit_index,res_index,flux_index,calibration_flag = True)
# Out:
# 2024-04-17 09:19:03,914 - qm - INFO     - Octave "octave1" Health check passed, current temperature 57
# INFO:qm:Octave "octave1" Health check passed, current temperature 57
# 2024-04-17 09:19:03,919 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-04-17 09:19:03,934 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates r2 for (LO, IF) = (7.054 GHz, -50.000 MHz)
# 2024-04-17 09:19:12,083 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# ------------------------------------- Calibrates q2 for (LO, IF) = (4.517 GHz, 200.000 MHz)
# 2024-04-17 09:19:26,523 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program

# %% [markdown]
# # TLS experiments

# %% [markdown]
# ## Set TLS index

# %%
TLS_index = 2

# %% [markdown]
# ## TLS T1

# %%
# set to qubit freq
machine.qubits[qubit_index].f_01 = machine.qubits[qubit_index].f_tls[0] + 0E6
machine.qubits[qubit_index].lo = machine.qubits[qubit_index].f_01 + 100E6
machine = Analysis.set_machine(machine)

# %%
# calibrate octave
Experiment.octave_calibration(qubit_index,res_index,flux_index,machine=machine,calibration_flag = True)
# Out:
# 2024-04-17 09:19:46,651 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-04-17 09:19:46,664 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates r2 for (LO, IF) = (7.054 GHz, -50.000 MHz)
# 2024-04-17 09:19:55,059 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# ------------------------------------- Calibrates q2 for (LO, IF) = (4.517 GHz, 200.000 MHz)
# 2024-04-17 09:20:09,460 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(200,500E3+1,2E4)
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.T1.TLS_T1(tau_sweep_abs, qubit_index, res_index, flux_index, TLS_index,
                   n_avg = 5E3, cd_time_qubit = 20E3, cd_time_TLS = 1000E3, simulate_flag = False, simulation_len = 15_000, plot_flag = True)
# Out:
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 160.16s
# Execution stopped by user!

# %%
# %matplotlib inline
TLS_T1 = Analysis.exp1D.T1(tau_sweep_abs,sig_amp,method = "exp")
# Out:
# Qubit T1 [us]: 34.6164851005693

# %% [markdown]
# # TLS drive

# %% [markdown]
# ## TLS spectroscopy

# %% [markdown]
# ### This cell is only for the first run, to estimate TLS freq

# %%
# TLS freq estimate based on SWAP flux amplitude
TLS_freq_est = np.polyval(machine.qubits[qubit_index].AC_tuning_curve,machine.flux_lines[flux_index].iswap.level)
TLS_freq_est = np.round(TLS_freq_est[0] * 1E6)
if len(machine.qubits[qubit_index].f_tls) < TLS_index + 2: # need to increase size
    machine.qubits[qubit_index].f_tls.append(int(TLS_freq_est.tolist()) + 0E6)
    machine.qubits[qubit_index].lo.append(int(TLS_freq_est.tolist()) - 200E6)
else: # just update the value
    machine.qubits[qubit_index].f_tls[TLS_index+1] = (int(TLS_freq_est.tolist()))
    machine.qubits[qubit_index].lo = int(TLS_freq_est.tolist()) - 200E6

# %% [markdown]
# ### This is when we already have calibrated TLS freq saved somewhere

# %%
# set the "qubit frequency"
machine.qubits[qubit_index].f_01 = machine.qubits[qubit_index].f_tls[TLS_index] + 0E6
machine.qubits[qubit_index].lo = machine.qubits[qubit_index].f_01 - 200E6
machine = Analysis.set_machine(machine)

# %%
# calibrate octave for TLS sweep
Experiment.octave_calibration(qubit_index,res_index,flux_index,machine = machine,calibration_flag = True)
# Out:
# 2024-04-12 12:39:54,209 - qm - INFO     - Octave "octave1" Health check passed, current temperature 57
# INFO:qm:Octave "octave1" Health check passed, current temperature 57
# 2024-04-12 12:39:54,213 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-04-12 12:39:54,230 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates r2 for (LO, IF) = (7.054 GHz, -50.000 MHz)
# 2024-04-12 12:40:01,995 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# ------------------------------------- Calibrates q2 for (LO, IF) = (4.514 GHz, 200.000 MHz)
# 2024-04-12 12:40:15,353 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program

# %%
# %matplotlib qt
TLS_freq_sweep = machine.qubits[qubit_index].f_01 + np.arange(-3E6,3E6+1,0.2E6)
machine, TLS_freq_sweep, sig_amp = Experiment.exp1D.Rabi.TLS_freq(TLS_freq_sweep, qubit_index, res_index, flux_index, TLS_index,
                  n_avg = 5E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, simulate_flag = False, simulation_len = 10_000, plot_flag = True, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 80.65s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 80.74s

# %%
# %matplotlib qt
TLS_freq_sweep = machine.qubits[qubit_index].f_tls[TLS_index] + np.arange(-150E6,150E6+1,1E6)
machine, TLS_freq_sweep, sig_amp = Experiment.exp1D.Rabi.TLS_freq(TLS_freq_sweep, qubit_index, res_index, flux_index, TLS_index,
                  n_avg = 1E3, cd_time_qubit = 20E3, cd_time_TLS = 800E3, simulate_flag = False, simulation_len = 10_000, plot_flag = True, machine = machine)

# %%
# %matplotlib inline
qubit_freq = Analysis.exp1D.peak_fit(x=TLS_freq_sweep,y=sig_amp,method="gaussian")
qubit_freq = int(qubit_freq.tolist())
# update TLS freq
machine.qubits[qubit_index].f_tls[TLS_index] = qubit_freq + 0E6
# set the "qubit frequency"
machine.qubits[qubit_index].f_01 = qubit_freq + 0E6
machine.qubits[qubit_index].lo = qubit_freq - 200E6
# save the parameters
machine = Analysis.set_machine(machine)
# Out:
# resonant frequency: 4716.936 MHz

# %%
# calibrate octave for TLS sweep
Experiment.octave_calibration(qubit_index,res_index,flux_index,machine = machine,calibration_flag = True)
# Out:
# 2024-04-15 17:31:08,901 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-04-15 17:31:08,911 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates r2 for (LO, IF) = (7.054 GHz, -50.000 MHz)
# 2024-04-15 17:31:17,492 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# ------------------------------------- Calibrates q2 for (LO, IF) = (4.517 GHz, 200.000 MHz)
# 2024-04-15 17:31:31,713 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program

# %% [markdown]
# ## Quantum jumps in TLS frequency

# %%
# %matplotlib qt
TLS_freq_sweep = machine.qubits[qubit_index].f_01 + np.arange(-3E6,3E6+1,1E6)
N_rounds = 4
machine, TLS_freq_sweep, tau, sig_amp, sig_phase = Experiment.exp2D.time.TLS_freq_time(TLS_freq_sweep, qubit_index, res_index, flux_index, TLS_index,
                  N_rounds, n_avg = 5E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, simulate_flag = False, simulation_len = 10_000, plot_flag = False, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=4/4) --> elapsed time: 68.06s

# %%
# Out:
# array([11.5961045, 34.3588885, 56.7920805, 79.252935 ])

# %%
tau xnew = 0.5*(x[0:-1]+x[1:])

# %%
plt.pcolormesh((tau[:-1]+tau[1:])/2, TLS_freq_sweep.T, sig_amp.T, shading='nearest')

# %% [markdown]
# ## TLS rabi

# %%
# %matplotlib qt
rabi_duration_sweep = np.arange(4, 180 + 0.1, 5)  # in units of clock cyles
machine, rabi_duration_sweep, sig_amp = Experiment.exp1D.Rabi.TLS_rabi_length(rabi_duration_sweep, qubit_index, res_index, flux_index, TLS_index,
                  n_avg = 5E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, simulate_flag = False, simulation_len = 10_000, plot_flag = True, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 93.77s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 93.86s

# %%
# %matplotlib inline
pi_pulse_length = Analysis.exp1D.rabi_length(rabi_duration_sweep,sig_amp,method = "decaying_time_rabi", plot_flag = True)
# Out:
# T2rabi: 6139.6 ns
# rabi_pi_pulse: 333.7 ns
# half period: 316.33 ns

# %%
pi_length = 336
if len(machine.qubits[qubit_index].pi_length_tls) < TLS_index + 1: # need to increase size
    machine.qubits[qubit_index].pi_length_tls.append(pi_length)
else: # just update the value
    machine.qubits[qubit_index].pi_length_tls[TLS_index] = pi_length
    
machine.qubits[qubit_index].pi_length_tls[0] = pi_length
machine = Analysis.set_machine(machine)

# %%
machine.qubits[qubit_index].rf_gain = 0
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## TLS Power Rabi

# %%
# %matplotlib qt
rabi_amp_sweep_rel = np.arange(0.1, 1, 0.05) 
machine, rabi_amp_sweep_abs, sig_amp = Experiment.exp1D.Rabi.TLS_rabi_amp(rabi_amp_sweep_rel, qubit_index, res_index, flux_index, TLS_index = TLS_index,  
                                          n_avg = 5E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, simulate_flag = False, simulation_len = 10_000,plot_flag = True, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 46.78s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 46.90s

# %%
# %matplotlib inline
pi_pulse_amp = Analysis.exp1D.rabi_length(rabi_amp_sweep_abs,sig_amp,method = "power_rabi", plot_flag = True)
# Out:
# rabi_pi_pulse_amp: 0.46742 V
# half period: 0.4370451 V
# Execution stopped by user!

# %%
if len(machine.qubits[qubit_index].pi_length_tls) < TLS_index + 1: # need to increase size
    machine.qubits[qubit_index].pi_amp_tls.append(pi_pulse_amp)
else: # just update the value
    machine.qubits[qubit_index].pi_amp_tls[TLS_index] = pi_pulse_amp
machine.qubits[qubit_index].pi_length_tls[0] = pi_pulse_amp
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## TLS Ramsey

# %%
# %matplotlib qt
ramsey_duration_sweep = np.arange(4, 1000 + 0.1, 2)  # in units of clock cyles
machine, ramsey_duration_sweep, sig_I = Experiment.exp1D.Ramsey.TLS_ramsey(ramsey_duration_sweep, qubit_index, res_index, flux_index, TLS_index,
          n_avg = 10E3, detuning = 7E6, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = True, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 2612.76s

# %%
# %matplotlib inline
q_T2star = Analysis.exp1D.ramsey(ramsey_duration_sweep, sig_I,plot_flag = True)
# Out:
# Qubit T2* [ns]: 661.1563263983008
# Detuning [MHz]: 7.123657739112519
# Exponent n: 1.261399606862469

# %% [markdown]
# ## TLS T1 with direct driving

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(200,500E3+1,2E4)
machine, tau_sweep_abs, sig_I = Experiment.exp1D.T1.TLS_T1_driving(tau_sweep_abs, qubit_index, res_index, flux_index, TLS_index,
                   n_avg = 5E3, cd_time_qubit = 20E3, cd_time_TLS = 1000E3, simulate_flag = False, simulation_len = 15_000, plot_flag = True)
# Out:
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 157.64s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 157.77s

# %%
# %matplotlib inline
TLS_T1 = Analysis.exp1D.T1(tau_sweep_abs,sig_I,method = "exp")
# Out:
# Qubit T1 [us]: 26.667463057069085

# %% [markdown]
# # TLS Dynamical Decoupling

# %%
#Parameters for DD sequences
# min_tau = 4
min_tau = 172/4
max_tau = 176/4 #in units of clock cycles
d_tau = 1

# %% [markdown]
# ## TLS echo

# %%
# %matplotlib qt
tau_sweep = np.arange(min_tau, max_tau + 0.1, d_tau)  # in units of clock cyles
machine, tau_sweep_abs, sig_I = Experiment.exp1D.DD.TLS_echo(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = True, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 834.88s

# %%
# %matplotlib inline
TLS_T1 = Analysis.exp1D.T1(tau_sweep_abs*2,sig_I,method = "exp")
# Out:
# Qubit T1 [us]: 2027.359931548211
# Execution stopped by user!

# %% [markdown]
# ## TLS CPMG2

# %%
# %matplotlib qt
tau_sweep = np.arange(min_tau, max_tau + 0.1, d_tau)  # in units of clock cyles
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 2, n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = True, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.34s
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.47s

# %%
print(sig_amp)

# %% [markdown]
# ## TLS CPMG4

# %%
# %matplotlib qt
tau_sweep = np.arange(min_tau, max_tau + 0.1, d_tau)  # in units of clock cyles
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 4, n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = True, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.41s

# %%
print(sig_amp)

# %% [markdown]
# ## TLS CPMG6

# %%
# %matplotlib qt
tau_sweep = np.arange(min_tau, max_tau + 0.1, d_tau)  # in units of clock cyles
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 6, n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.40s
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.44s

# %%
print(sig_amp)

# %% [markdown]
# ## TLS CPMG8

# %%
# %matplotlib qt
tau_sweep = np.arange(min_tau, max_tau + 0.1, d_tau)  # in units of clock cyles
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 8, n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.46s
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.51s

# %%
print(sig_amp)

# %% [markdown]
# ## TLS CPMG 10

# %%
# %matplotlib qt
tau_sweep = np.arange(min_tau, max_tau + 0.1, d_tau)  # in units of clock cyles
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 10, n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.50s
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.54s

# %%
print(sig_amp)

# %% [markdown]
# ## TLS CPMG12

# %%
# %matplotlib qt
tau_sweep = np.arange(min_tau, max_tau + 0.1, d_tau)  # in units of clock cyles
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 12, n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.59s
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.64s

# %%
print(sig_amp)

# %% [markdown]
# ## TLS CPMG 14

# %%
# %matplotlib qt
tau_sweep = np.arange(min_tau, max_tau + 0.1, d_tau)  # in units of clock cyles
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 14, n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.59s
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.63s

# %%
print(sig_amp)

# %% [markdown]
# ## TLS CPMG16

# %%
# %matplotlib qt
tau_sweep = np.arange(min_tau, max_tau + 0.1, d_tau)  # in units of clock cyles
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 16, n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.51s
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.57s

# %%
print(sig_amp)

# %% [markdown]
# ## TLS CPMG 18

# %%
# %matplotlib qt
tau_sweep = np.arange(min_tau, max_tau + 0.1, d_tau)  # in units of clock cyles
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 18, n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.60s
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.65s

# %%
print(sig_amp)

# %% [markdown]
# ## TLS CPMG20

# %%
# %matplotlib qt
tau_sweep = np.arange(min_tau, max_tau + 0.1, d_tau)  # in units of clock cyles
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 20, n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.70s
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.74s

# %%
print(sig_amp)

# %% [markdown]
# ## TLS CPMG 22

# %%
# %matplotlib qt
tau_sweep = np.arange(min_tau, max_tau + 0.1, d_tau)  # in units of clock cyles
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 22, n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.63s
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 10.68s

# %%
print(sig_amp)

# %% [markdown]
# ## TLS CPMG24

# %%
# %matplotlib qt
tau_sweep = np.arange(min_tau, max_tau + 0.1, d_tau)  # in units of clock cyles
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 24, n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 3
#       1 get_ipython().run_line_magic('matplotlib', 'qt')
#       2 tau_sweep = np.arange(min_tau, max_tau + 0.1, d_tau)  # in units of clock cyles
# ----> 3 machine, tau_sweep_abs, sig_I = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
#       4           N_CPMG = 24, n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
#
# File ~\QM\QM_UALA\TLS_T1\ExperimentClass_1D.py:4374, in EH_DD.TLS_CPMG(self, tau_sweep, qubit_index, res_index, flux_index, TLS_index, if_x_pi2, N_CPMG, n_avg, cd_time_qubit, cd_time_TLS, tPath, f_str_datetime, simulate_flag, simulation_len, plot_flag, machine)
#    4372 	job.get_simulated_samples().con1.plot()
#    4373 else:
# -> 4374 	qm = qmm.open_qm(config)
#    4375 	job = qm.execute(tls_echo)
#    4376 	results = fetching_tool(job, data_list=["I", "Q", "iteration"], mode="live")
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\qm\quantum_machines_manager.py:192, in QuantumMachinesManager.open_qm(self, config, close_other_machines, validate_with_protobuf, use_calibration_data, **kwargs)
#     188 qua_config = self._load_config(config, disable_marshmallow_validation=validate_with_protobuf)
#     190 machine_id = self._frontend.open_qm(qua_config, close_other_machines)
# --> 192 return QuantumMachine(
#     193     machine_id=machine_id,
#     194     pb_config=qua_config,
#     195     frontend_api=self._frontend,
#     196     capabilities=self._caps,
#     197     store=self._store,
#     198     octave_config=self._octave_config,
#     199     octave_manager=self._octave_manager,
#     200 )
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\qm\QuantumMachine.py:81, in QuantumMachine.__init__(self, machine_id, pb_config, frontend_api, capabilities, store, octave_manager, octave_config)
#      79 for element in self._elements.values():
#      80     if isinstance(element, ElementWithOctave):
# ---> 81         element.set_client()
#
# File ~\.conda\envs\labber-qm-env\lib\contextlib.py:120, in _GeneratorContextManager.__exit__(self, type, value, traceback)
#     118 if type is None:
#     119     try:
# --> 120         next(self.gen)
#     121     except StopIteration:
#     122         return False
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\qm\octave\octave_manager.py:228, in OctaveManager.batch_mode(self)
#     226 self.start_batch_mode()
#     227 yield
# --> 228 self.end_batch_mode()
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\qm\octave\octave_manager.py:221, in OctaveManager.end_batch_mode(self)
#     219 def end_batch_mode(self):
#     220     for client in self._octave_clients.values():
# --> 221         client.end_batch_mode()
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\octave_sdk\octave.py:1103, in Octave.end_batch_mode()
#    1101 @staticmethod
#    1102 def end_batch_mode():
# -> 1103     BatchSingleton().end_batch_mode()
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\octave_sdk\batch.py:31, in BatchSingleton.end_batch_mode(self)
#      29 if self._batch_mode:
#      30     for callback in self._end_batch_callbacks.values():
# ---> 31         callback()
#      32     self._cached_updates = defaultdict(dict)
#      33     self._cached_modules = defaultdict(dict)
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\octave_sdk\_octave_client.py:232, in OctaveClient._end_batch_callback(self)
#     231 def _end_batch_callback(self):
# --> 232     self._send_update(list(BatchSingleton().get_cached_updates(self).values()))
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\octave_sdk\_octave_client.py:267, in OctaveClient._send_update(self, updates)
#     265 update_request = UpdateRequest(updates=updates)
#     266 future = asyncio.run_coroutine_threadsafe(self._service.update(update_request), loop=self._event_loop)
# --> 267 response = future.result()
#     268 if not response.success:
#     269     raise Exception(f"Octave update failed: {response.error_message}")
#
# File ~\.conda\envs\labber-qm-env\lib\concurrent\futures\_base.py:439, in Future.result(self, timeout)
#     436 elif self._state == FINISHED:
#     437     return self.__get_result()
# --> 439 self._condition.wait(timeout)
#     441 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     442     raise CancelledError()
#
# File ~\.conda\envs\labber-qm-env\lib\threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:

# %%
print(sig_amp)

# %% [markdown]
# ## TLS CPMG 26

# %%
# %matplotlib qt
tau_sweep = np.arange(min_tau, max_tau + 0.1, d_tau)  # in units of clock cyles
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 26, n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)

# %%
print(sig_amp)

# %% [markdown]
# ## TLS CPMG28

# %%
# %matplotlib qt
tau_sweep = np.arange(min_tau, max_tau + 0.1, d_tau)  # in units of clock cyles
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 28, n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 3574.02s

# %% [markdown]
# ## TL CPMG 30

# %%
# %matplotlib qt
tau_sweep = np.arange(min_tau, max_tau + 0.1, d_tau)  # in units of clock cyles
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 30, n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)

# %% [markdown]
# ## TLS CPMG32

# %%
# %matplotlib qt
tau_sweep = np.arange(min_tau, max_tau + 0.1, d_tau)  # in units of clock cyles
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.DD.TLS_CPMG(tau_sweep, qubit_index, res_index, flux_index, TLS_index,
          N_CPMG = 32, n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = False, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 1681.31s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 1681.38s

# %% [markdown]
# ## CPMG Rabi

# %%
N_sweep = np.arange(2,28+1,2)
tau_val = int(172)
machine, N_sweep, sig_amp, sig_phase = Experiment.exp1D.DD.TLS_CPMG_Rabi(tau_val, N_sweep, qubit_index, res_index, flux_index, TLS_index, 
                                                              n_avg = 10E3, cd_time_qubit = 20E3, cd_time_TLS = 500E3, plot_flag = False, 
                                                                         simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=14/14) --> elapsed time: 61.85s

# %%
plt.plot(N_sweep, sig_amp)
