# %% [markdown]
# ## Single-Shot Readout Calibration for LA Q2

# %% [markdown]
# ### Using Experiment and Analysis Class, make sure to update qubit #

# %%
from qm.qua import *
from qm import QuantumMachinesManager, SimulationConfig, LoopbackInterface, generate_qua_script
from qm.octave import *
from qm.octave.octave_manager import ClockMode
from configuration import *
from scipy import signal
from qualang_tools.bakery import baking
from qualang_tools.units import unit
from qm.octave import QmOctaveConfig
from set_octave import ElementsSettings, octave_settings
from quam import QuAM
from scipy.io import savemat, loadmat
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter
from qutip import *
from typing import Union
from macros import *
import datetime 
import os
import time
import warnings
import json
import matplotlib.pyplot as plt
import numpy as np
import Labber

from ExperimentClass import ExperimentHandle
from AnalysisClass import AnalysisHandle

warnings.filterwarnings("ignore")

qubit_index = 5 # for LA Q2
res_index = 5 # for LA Q2
flux_index = 5 # for LA Q2
TLS_index = 0 # for TLS of interest
# Out:
# 2024-03-20 15:51:44,044 - qm - INFO     - Starting session: 7a21e23b-644a-40e9-9e8e-29a99f5d174f

# %%
Experiment = ExperimentHandle()
Analysis = AnalysisHandle()
machine = Analysis.get_machine()

# %%
# initialize Labber-controlled hardware
Experiment.set_Labber(Analysis.get_machine(), qubit_index, res_index, flux_index)
# set to sweet spot
machine = Experiment.set_QDAC(qubit_index,res_index,flux_index,machine.flux_lines[flux_index].max_frequency_point)
# set octave to external clock
#Experiment.set_external_clock()

# %%
# Set the qubit freq, in case I was working with something else
machine.qubits[qubit_index].f_01 = machine.qubits[qubit_index].f_tls[0] + 0E6
machine.qubits[qubit_index].lo = machine.qubits[qubit_index].f_01 + 50E6
machine = Analysis.set_machine(machine)

# %%
# octave calibration
Experiment.octave_calibration(qubit_index,res_index,flux_index,calibration_flag = True)
# Out:
# 2024-03-20 15:52:04,100 - qm - INFO     - Octave "octave1" Health check passed, current temperature 57
# INFO:qm:Octave "octave1" Health check passed, current temperature 57
# 2024-03-20 15:52:04,104 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-03-20 15:52:04,119 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates r5 for (LO, IF) = (6.170 GHz, -50.000 MHz)
# 2024-03-20 15:52:11,974 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# ------------------------------------- Calibrates q5 for (LO, IF) = (5.584 GHz, -50.000 MHz)
# 2024-03-20 15:52:25,338 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program

# %% [markdown]
# ## 1D resonator spectroscopy

# %%
# %matplotlib qt
machine = Analysis.get_machine()
res_freq_sweep = machine.resonators[res_index].f_readout + np.arange(-5E6,5E6 + 1.0,0.05E6)
machine, res_freq_sweep, sig_amp = Experiment.exp1D.RR.rr_freq(res_freq_sweep, qubit_index, res_index, flux_index, 
                           n_avg = 1E3, cd_time = 5E3, readout_state = 'g', simulate_flag = False, simulation_len = 1000)
# Out:
# Progress: [##################################################] 100.0% (n=1000/1000.0) --> elapsed time: 0.96s

# %%
# find the minimal
# %matplotlib inline
res_freq = Analysis.exp1D.rr_freq(res_freq_sweep, sig_amp)
if False:
    machine.resonators[res_index].f_readout = res_freq.tolist() + 0E6
    machine.resonators[res_index].lo = machine.resonators[res_index].f_readout + 50E6
    machine = Analysis.set_machine(machine)
# Out:
# resonator frequency: 6119.757 MHz
# Execution stopped by user!

# %% [markdown]
# ## 1D qubit spectroscopy

# %%
# for the DC flux
#qubit_freq_est = np.polyval(machine.qubits[qubit_index].DC_tuning_curve,machine.flux_lines[flux_index].max_frequency_point) * 1E6 # in Hz
# for the fast flux
qubit_freq_sweep = machine.qubits[qubit_index].f_01 + np.arange(-30E6, 100E6 + 1, 1E6)
    
# %matplotlib qt
machine, qubit_freq_sweep, sig_amp = Experiment.exp1D.Rabi.qubit_freq(qubit_freq_sweep, qubit_index, res_index, flux_index, 
                                      pi_amp_rel = 1.5, ff_amp = 0.0, n_avg = 1E3, cd_time = 20E3, plot_flag = True, 
                                      simulate_flag = False, simulation_len = 4000)
# Out:
# Progress: [##################################################] 100.0% (n=1000/1000.0) --> elapsed time: 2.61s
# Progress: [##################################################] 100.0% (n=1000/1000.0) --> elapsed time: 2.70s

# %%
# %matplotlib inline
qubit_freq = Analysis.exp1D.peak_fit(x=qubit_freq_sweep,y=sig_amp,method="gaussian")
qubit_freq = int(qubit_freq.tolist())
machine.qubits[qubit_index].f_01 = qubit_freq + 0E6
machine.qubits[qubit_index].f_tls[0] = qubit_freq + 0E6
machine.qubits[qubit_index].lo = qubit_freq + 50E6
machine = Analysis.set_machine(machine)
# Out:
# resonant frequency: 5535.865 MHz

# %% [markdown]
# ## Measure single-shot I, Q blobs

# %%
# %matplotlib inline
machine, Ig, Qg, Ie, Qe = Experiment.exp1D.RR.single_shot_IQ_blob(machine.resonators[res_index].f_readout, qubit_index, res_index, flux_index,
                              n_avg = 120E3, cd_time = 25E3, plot_flag = False)

# %%
angle, threshold, fidelity, gg, ge, eg, ee = Analysis.exp1D.two_state_discriminator(Ig, Qg, Ie, Qe, plot_flag=True)
# Out:
# 			Fidelity Matrix:
# 			-----------------
# 			| 0.913 | 0.087 |
# 			----------------
# 			| 0.832 | 0.168 |
# 			-----------------
# 			IQ plane rotated by: 271.6°
# 			Threshold: 2.478e-03
# 			Fidelity: 54.0%
# Execution stopped by user!

# %%
# set the rotation angle
machine.resonators[res_index].rotation_angle -= angle.item()
machine.resonators[res_index].ge_threshold = threshold.item()
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## optimize single-shot frequency

# %%
res_freq_sweep = machine.resonators[res_index].f_readout + np.arange(-2E6, 2E6 + 1, 0.02E6)

# %matplotlib qt
machine, SNR, res_freq_opt = Experiment.exp1D.RR.single_shot_freq_optimization(res_freq_sweep, qubit_index, res_index, flux_index,
                              n_avg = 50E3, cd_time = 10E3, plot_flag = True)
# Out:
# Progress: [##################################################] 100.0% (n=50000/50000.0) --> elapsed time: 244.59s
# The optimal readout frequency is 6226809034.0 Hz (SNR=1.5088437776101284)

# %%
machine.resonators[res_index].f_readout = res_freq_opt.tolist() + 0E6
machine.resonators[res_index].lo = machine.resonators[res_index].f_readout + 50E6
machine = Analysis.set_machine(machine)

# %%
# octave calibration
Experiment.octave_calibration(qubit_index,res_index,flux_index,calibration_flag = True)
# Out:
# 2024-01-02 14:59:19,763 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-02 14:59:19,773 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates r4 for (LO, IF) = (6.277 GHz, -50.000 MHz)
# 2024-01-02 14:59:27,012 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# ------------------------------------- Calibrates q4 for (LO, IF) = (5.785 GHz, -50.000 MHz)
# 2024-01-02 14:59:39,759 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program

# %% [markdown]
# ## optimize single-shot amplitude

# %%
res_amp_sweep = np.arange(0.5,2 + 1E-4, 0.01)

# %matplotlib qt
machine, res_amp_sweep_abs, fidelity, res_amp_opt = Experiment.exp1D.RR.single_shot_amp_optimization(res_amp_sweep, qubit_index, res_index, flux_index,
                              n_avg = 40E3, cd_time = 25E3, plot_flag = True)
# Out:
# some rel amps > 2.0, removed from experiment run
# some abs amps > 0.5, removed from experiment run
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.05s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.07s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.09s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.12s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.14s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.16s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.18s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.20s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.22s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.25s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.27s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.30s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.32s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.35s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.37s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.39s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.42s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.44s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.46s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.48s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.50s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.53s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.56s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.58s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.61s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 237.63s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.43s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.45s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.46s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.48s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.50s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.51s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.53s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.55s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.56s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.58s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.60s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.61s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.63s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.64s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.66s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.67s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.69s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.71s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.72s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.73s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.75s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.76s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.78s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.80s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.82s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.83s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.85s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.86s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.88s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.89s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.91s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.93s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.94s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.96s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.97s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 239.99s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 241.24s
# Progress: [##################################################] 100.0% (n=117/117) --> elapsed time: 241.26s
# The optimal readout amplitude is 465.000 mV (Fidelity=54.1%)

# %%
machine.resonators[res_index].readout_pulse_amp = 0.25
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## optimize single-shot readout duration

# %%
readout_len = 4E3
ringdown_len = 1E3
division_length = 10

# %matplotlib qt
machine, res_duration_sweep, SNR, opt_readout_length = Experiment.exp1D.RR.single_shot_duration_optimization(readout_len, ringdown_len, division_length, 
                            qubit_index, res_index, flux_index, n_avg = 20E3, cd_time = 25E3, plot_flag = True)
# Out:
# Integration weights chunk-size length in clock cycles: 10
# The readout has been sliced in the following number of divisions 125
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 10.20s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 10.60s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 11.05s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 11.45s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 11.82s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 12.33s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 12.73s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 13.18s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 13.58s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 13.99s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 14.40s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 14.80s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 15.20s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 15.60s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 16.01s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 16.41s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 16.92s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 17.33s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 17.76s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 18.19s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 18.62s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 19.02s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 19.42s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 19.80s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 20.19s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 20.56s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 21.07s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 21.45s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 21.84s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 22.20s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 22.60s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 23.01s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 23.39s
# The optimal readout length is 1200 ns (SNR=0.040549494918509094)

# %%
machine.resonators[res_index].readout_pulse_length = 1200
machine = Analysis.set_machine(machine)
