# %% [markdown]
# # Basic characterizations of LA Q1
# ### using Experiment and Analysis classes

# %%
from qm.qua import *
from qm import QuantumMachinesManager, SimulationConfig, LoopbackInterface, generate_qua_script
from qm.octave import *
from qm.octave.octave_manager import ClockMode
from configuration import *
from scipy import signal
from qualang_tools.bakery import baking
from qualang_tools.units import unit
from qm.octave import QmOctaveConfig
from set_octave import ElementsSettings, octave_settings
from quam import QuAM
from scipy.io import savemat, loadmat
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter
from qutip import *
from typing import Union
from macros import *
import datetime 
import os
import time
import warnings
import json
import matplotlib.pyplot as plt
import numpy as np
import Labber

from ExperimentClass import ExperimentHandle
from AnalysisClass import AnalysisHandle

warnings.filterwarnings("ignore")

qubit_index = 4 # for LA Q1
res_index = 4 # for LA Q1
flux_index = 4 # for LA Q1
TLS_index = 0 # for TLS of interest
# Out:
# 2024-01-23 11:28:54,358 - qm - INFO     - Starting session: bfd7e80e-511d-4396-83a1-a6f75544112d

# %%
Experiment = ExperimentHandle()
Analysis = AnalysisHandle()
machine = Analysis.get_machine()

# %%
# initialize Labber-controlled hardware
Experiment.set_Labber(Analysis.get_machine(), qubit_index, res_index, flux_index)
# set octave to external clock
#Experiment.set_external_clock()

# %%
machine.qubits[qubit_index].lo = machine.qubits[qubit_index].f_01 + 50e6
machine = Analysis.set_machine(machine)

# %%
# this updates the octave settings, including rf_gain and rf_output_mode
Experiment.octave_calibration(qubit_index,res_index,flux_index,calibration_flag = False)
# Out:
# 2024-01-23 11:29:38,194 - qm - INFO     - Octave "octave1" Health check passed, current temperature 58
# INFO:qm:Octave "octave1" Health check passed, current temperature 58
# 2024-01-23 11:29:38,198 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 11:29:38,215 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed

# %%
# octave calibration
Experiment.octave_calibration(qubit_index,res_index,flux_index,calibration_flag = True)
# Out:
# 2024-01-23 15:31:34,694 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 15:31:34,708 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates r4 for (LO, IF) = (6.277 GHz, -50.000 MHz)
# 2024-01-23 15:31:42,368 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# ------------------------------------- Calibrates q4 for (LO, IF) = (3.874 GHz, -50.000 MHz)
# 2024-01-23 15:31:53,803 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program

# %% [markdown]
# ## Time of flight

# %%
# time_of_flight
# experiment
machine, adc1, adc2, adc1_single, adc2_single = Experiment.exp1D.RR.time_of_flight(qubit_index,res_index,flux_index, n_avg = 10E3, cd_time = 10E3, simulate_flag = False, simulation_len = 1000)
# plot
# %matplotlib inline
dc_offset_i, dc_offset_q, delay = Analysis.exp1D.time_of_flight(adc1,adc2,adc1_single,adc2_single)
# Out:
# DC offset to add to I: -0.000286 V
# DC offset to add to Q: -0.000289 V
# TOF to add: 0.0 ns

# %%
# update the offset
machine.global_parameters.con1_downconversion_offset_I += dc_offset_i.item()
machine.global_parameters.con1_downconversion_offset_Q += dc_offset_q.item()
#machine.global_parameters.time_of_flight = 304-0
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## 1D RO resonator spectroscopy

# %%
# %matplotlib qt
machine = Analysis.get_machine()
res_freq_sweep = machine.resonators[res_index].f_readout + np.arange(-10E6,10E6 + 1.0,0.05E6)
machine, res_freq_sweep, sig_amp = Experiment.exp1D.RR.rr_freq(res_freq_sweep, qubit_index, res_index, flux_index, 
                            n_avg = 1E3, cd_time = 5E3, readout_state = 'g', simulate_flag = False, simulation_len = 1000)
# Readout in excited state
# machine, res_freq_sweep, sig_amp = Experiment.exp1D.RR.rr_freq(res_freq_sweep, qubit_index, res_index, flux_index, 
#                           n_avg = 1E3, cd_time = 5E3, readout_state = 'e', simulate_flag = False, simulation_len = 1000)
# Out:
# Progress: [##################################################] 100.0% (n=1000/1000.0) --> elapsed time: 2.03s
# Progress: [##################################################] 100.0% (n=1000/1000.0) --> elapsed time: 2.12s

# %%
# find the minimal
# %matplotlib inline
res_freq = Analysis.exp1D.rr_freq(res_freq_sweep, sig_amp)
machine.resonators[res_index].f_readout = res_freq.tolist() + 0E6
machine.resonators[res_index].lo = res_freq.tolist() + 50E6
machine = Analysis.set_machine(machine)
# Out:
# resonator frequency: 6227.186 MHz
# Execution stopped by user!

# %%
# octave calibration
Experiment.octave_calibration(qubit_index,res_index,flux_index,calibration_flag = True)
# Out:
# 2024-01-23 11:30:06,184 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 11:30:06,194 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates r4 for (LO, IF) = (6.277 GHz, -50.000 MHz)
# 2024-01-23 11:30:13,050 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# ------------------------------------- Calibrates q4 for (LO, IF) = (5.775 GHz, -50.000 MHz)
# 2024-01-23 11:30:25,373 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program

# %%
machine.resonators[res_index].f_readout
# Out:
# 6226692408.0

# %% [markdown]
# ## 2D RO resonator spectroscopy vs DC flux

# %%
res_freq_sweep = np.arange(6.212E9,6.230E9 + 1.0,0.1E6)
dc_flux_sweep = np.arange(-9,9.001,0.5)
# %matplotlib qt
machine, res_freq_sweep, dc_flux_sweep, sig_amp = Experiment.exp2D.RR.rr_vs_dc_flux(res_freq_sweep, dc_flux_sweep, qubit_index, res_index, flux_index, n_avg = 10E3, cd_time = 10E3)
# Out:
# Progress: [##################################################] 100.0% (n=37/37)

# %%
# %matplotlib inline
ham_param = Analysis.exp2D.rr_vs_dc_flux(res_freq_sweep, dc_flux_sweep, sig_amp, init_guess = [6227, 200, 30E3, 0.05, 0.4, 100])
poly_param = Analysis.exp2D.qubit_vs_dc_flux_guess(ham_param)

# %%
# save the fitting parameters
machine.resonators[res_index].tuning_curve = ham_param.tolist()
machine.qubits[qubit_index].DC_tuning_curve = poly_param.tolist()
machine = Analysis.set_machine(machine)

# %%
# save the sweep spot flux according to fitted parameter
machine.flux_lines[flux_index].max_frequency_point = Analysis.get_sweept_spot(machine.qubits[qubit_index].DC_tuning_curve)
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## 1D qubit spectroscopy @ sweep spot

# %%
# set to sweet spot
machine = Experiment.set_QDAC(qubit_index,res_index,flux_index,machine.flux_lines[flux_index].max_frequency_point)

# %%
# calibrate RO
# %matplotlib qt
#res_freq_sweep = np.arange(7.2575E9,7.2675E9 + 1.0,0.03E6)
ham_param = machine.resonators[res_index].tuning_curve
res_freq_est = Analysis.exp2D.ham([machine.flux_lines[flux_index].max_frequency_point], ham_param[0], ham_param[1], ham_param[2], ham_param[3], ham_param[4], ham_param[5], output_flag = 1) * 1E6 # to Hz
res_freq_sweep = int(res_freq_est[0]) + np.arange(-5E6, 5E6 + 1, 0.05E6)
machine, res_freq_sweep, sig_amp = Experiment.exp1D.RR.rr_freq(res_freq_sweep, qubit_index, res_index, flux_index, 
                       n_avg = 5E3, cd_time = 5E3, plot_flag = False, simulate_flag = False, simulation_len = 1000)
# %matplotlib inline
res_freq = Analysis.exp1D.rr_freq(res_freq_sweep, sig_amp)
res_freq = int(res_freq.tolist())
machine.resonators[res_index].f_readout = res_freq + 0E6
machine.resonators[res_index].lo = res_freq + 50E6
machine = Analysis.set_machine(machine)
# Out:
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 5.72s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 5.76s
# resonator frequency: 6226.692 MHz

# %%
# calibrate octave
Experiment.octave_calibration(qubit_index,res_index,flux_index)
# Out:
# 2024-01-23 12:18:15,919 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 12:18:15,928 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates r4 for (LO, IF) = (6.277 GHz, -50.000 MHz)
# 2024-01-23 12:18:23,389 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# ------------------------------------- Calibrates q4 for (LO, IF) = (5.775 GHz, -50.000 MHz)
# 2024-01-23 12:18:35,954 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program

# %%
machine.qubits[qubit_index].f_01 = machine.qubits[qubit_index].f_tls[0] + 0E6
machine.qubits[qubit_index].lo = machine.qubits[qubit_index].f_01 + 50E6
machine = Analysis.set_machine(machine)
Experiment.octave_calibration(qubit_index,res_index,flux_index,machine=machine,calibration_flag=True)
# Out:
# 2024-01-23 15:33:47,762 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 15:33:47,773 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates r4 for (LO, IF) = (6.277 GHz, -50.000 MHz)
# 2024-01-23 15:33:55,528 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# ------------------------------------- Calibrates q4 for (LO, IF) = (5.775 GHz, -50.000 MHz)
# 2024-01-23 15:34:07,561 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program

# %%
if False: # for the DC flux
    qubit_freq_est = np.polyval(machine.qubits[qubit_index].DC_tuning_curve,machine.flux_lines[flux_index].max_frequency_point) * 1E6 # in Hz
else: # for the fast flux
    qubit_freq_est = np.polyval(machine.qubits[qubit_index].AC_tuning_curve,0.0) * 1E6 # in Hz
    
qubit_freq_sweep = int(qubit_freq_est) + np.arange(-50E6, 50E6 + 1, 1E6)
    
# %matplotlib qt
machine, qubit_freq_sweep, sig_amp = Experiment.exp1D.Rabi.qubit_freq(qubit_freq_sweep, qubit_index, res_index, flux_index, 
                                      pi_amp_rel = 1.0, ff_amp = 0.0, n_avg = 10E3, cd_time = 20E3, plot_flag = False, 
                                      simulate_flag = False, simulation_len = 4000)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 21.18s
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 21.22s

# %%
# %matplotlib inline
qubit_freq = Analysis.exp1D.peak_fit(x=qubit_freq_sweep,y=sig_amp,method="gaussian")
qubit_freq = int(qubit_freq.tolist())
machine.qubits[qubit_index].f_01 = qubit_freq + 0E6
machine.qubits[qubit_index].f_tls[0] = qubit_freq + 0E6
machine.qubits[qubit_index].lo = qubit_freq + 50E6
machine = Analysis.set_machine(machine)
# Out:
# resonant frequency: 5724.966 MHz

# %%
# calibrate octave
Experiment.octave_calibration(qubit_index,res_index,flux_index,machine=machine)
# Out:
# 2024-01-23 12:27:59,968 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 12:27:59,975 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates r4 for (LO, IF) = (6.277 GHz, -50.000 MHz)
# 2024-01-23 12:28:06,843 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# ------------------------------------- Calibrates q4 for (LO, IF) = (5.775 GHz, -50.000 MHz)
# 2024-01-23 12:28:19,424 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program

# %% [markdown]
# ## Rabi

# %% [markdown]
# ### time rabi

# %%
# %matplotlib qt
rabi_duration_sweep = np.arange(4, 40 + 0.1, 1)  # in units of clock cyles
rabi_duration_sweep = rabi_duration_sweep.astype(int)
machine, rabi_duration_sweep, sig_amp = Experiment.exp1D.Rabi.rabi_length(rabi_duration_sweep, qubit_index, res_index, flux_index, 
          pi_amp_rel = 1.0, n_avg = 2E3, cd_time = 25E3, plot_flag = False, machine = machine, simulate_flag = False, simulation_len = 10_000)
# Out:
# Progress: [##################################################] 100.0% (n=2000/2000.0) --> elapsed time: 1.78s
# Progress: [##################################################] 100.0% (n=2000/2000.0) --> elapsed time: 1.82s

# %%
# %matplotlib inline
pi_pulse_length = Analysis.exp1D.rabi_length(rabi_duration_sweep,sig_amp,plot_flag = True)
# Out:
# rabi_pi_pulse: 100.0 ns
# half period: 103.23 ns

# %%
machine.qubits[qubit_index].pi_length[0] = 100
#machine.qubits[qubit_index].pi_amp[0] = 0.02
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### power rabi

# %%
# %matplotlib qt
rabi_amp_sweep_rel = np.arange(0.2, 2.0, 0.05) 
machine, rabi_amp_sweep_abs, sig_amp = Experiment.exp1D.Rabi.rabi_amp(rabi_amp_sweep_rel, qubit_index, res_index, flux_index, 
                                          n_avg = 10E3, cd_time = 40E3, plot_flag = False, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 14.64s
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 14.69s

# %%
# %matplotlib inline
pi_pulse_amp = Analysis.exp1D.rabi_length(rabi_amp_sweep_abs,sig_amp,method = "power_rabi", plot_flag = True)
# Out:
# rabi_pi_pulse_amp: 0.01872 V
# half period: 0.0177183 V

# %%
machine.qubits[qubit_index].pi_amp[0] = pi_pulse_amp.item()
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## T1

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(100,12E3+1,300)
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.T1.qubit_T1(tau_sweep_abs, qubit_index, res_index, flux_index, 
                   n_avg = 5E3, cd_time = 30E3, simulate_flag = False, simulation_len = 15_000, plot_flag = False)
# Out:
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 7.31s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 7.35s

# %%
# %matplotlib inline
q_T1 = Analysis.exp1D.T1(tau_sweep_abs,sig_amp,method = "exp")
machine.qubits[qubit_index].T1 = int(q_T1.tolist())
machine = Analysis.set_machine(machine)
# Out:
# Qubit T1 [us]: 1.7043231129703251

# %% [markdown]
# ## Ramsey

# %%
# %matplotlib qt
ramsey_duration_sweep = np.arange(4, 1500 + 0.1, 5)  # in units of clock cyles
machine, ramsey_duration_sweep, sig_amp = Experiment.exp1D.Ramsey.ramsey(ramsey_duration_sweep, qubit_index, res_index, flux_index, 
          n_avg = 10E3, detuning = 2E6, cd_time = 10E3, plot_flag = True, simulate_flag = False, simulation_len = 20_000, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 41.11s

# %%
# %matplotlib inline
q_T2star = Analysis.exp1D.ramsey(ramsey_duration_sweep, sig_amp,plot_flag = True)
machine.qubits[qubit_index].T2 = int(q_T2star.tolist())
machine = Analysis.set_machine(machine)
# Out:
# Qubit T2* [ns]: 2042.7806503849777
# Detuning [MHz]: 1.7769575051760431
# Exponent n: 0.7818769093316482

# %% [markdown]
# ## ef transition

# %% [markdown]
# ### ef frequency

# %%
# %matplotlib qt
ef_freq_sweep = machine.qubits[qubit_index].f_01 + np.arange(-200E6, -150E6 + 1, 0.5E6) 
machine, ef_freq_sweep, sig_amp = Experiment.exp1D.Rabi.ef_freq(ef_freq_sweep, qubit_index, res_index, flux_index, 
                      pi_amp_rel = 1, pi_amp_rel_ef = 1.0, n_avg = 2E3, cd_time = 20E3, readout_state = 'g', plot_flag = False, 
                      simulate_flag = False, simulation_len = 4000)

# %%
# %matplotlib inline
ef_freq = Analysis.exp1D.peak_fit(x=ef_freq_sweep,y=sig_amp,method="gaussian")

# %%
machine.qubits[qubit_index].anharmonicity = machine.qubits[qubit_index].f_01 - int(ef_freq)
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### ef transition time Rabi

# %%
# %matplotlib qt
rabi_duration_sweep = np.arange(4, 80 + 0.1, 1)  # in units of clock cyles
rabi_duration_sweep = rabi_duration_sweep.astype(int)
machine, rabi_duration_sweep, sig_amp = Experiment.exp1D.Rabi.ef_rabi_length(rabi_duration_sweep, qubit_index, res_index, flux_index, 
          pi_amp_rel = 1.0, pi_amp_rel_ef = 1.0,  n_avg = 2E3, cd_time = 20E3, readout_state = 'g', plot_flag = False, machine = machine, simulate_flag = False, simulation_len = 10_000)

# %%
# %matplotlib inline
pi_pulse_length = Analysis.exp1D.rabi_length(rabi_duration_sweep,sig_amp,plot_flag = True)

# %%
machine.qubits[qubit_index].pi_length[1] = 80
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### ef transition power Rabi

# %%
# %matplotlib qt
rabi_amp_sweep_rel = np.arange(0.2, 3.0, 0.05) 
machine, rabi_amp_sweep_abs, sig_amp = Experiment.exp1D.Rabi.ef_rabi_amp(rabi_amp_sweep_rel, qubit_index, res_index, flux_index, 
                          pi_amp_rel = 1.0, n_avg = 10E3, cd_time = 20E3, readout_state = 'g', plot_flag = False, machine = machine,
                          simulate_flag = False, simulation_len = 1000)

# %%
# %matplotlib inline
pi_pulse_amp = Analysis.exp1D.rabi_length(rabi_amp_sweep_abs,sig_amp,method = "power_rabi", plot_flag = True)

# %%
machine.qubits[qubit_index].pi_amp[1] = pi_pulse_amp
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## 2D qubit spectroscopy vs dc flux

# %%
machine = Analysis.get_machine()

# %%
# try the experiment
# %matplotlib qt
dc_flux_sweep = machine.flux_lines[flux_index].max_frequency_point + np.arange(-0.4,0.4+1E-4,0.02)
_,qubit_freq_sweep,dc_flux_sweep,sig_amp_qubit = Experiment.exp2D.Rabi.qubit_freq_vs_dc_flux(dc_flux_sweep,qubit_index,res_index,flux_index,
                                 n_avg = 2E3, cd_time = 10E3, pi_amp_rel = 1.0, plot_flag = True)
# Out:
# Progress: [##################################################] 100.0% (n=41/41) --> elapsed time: 508.54s

# %%
# udpate the sweet spot
# %matplotlib inline
poly_param = Analysis.exp2D.qubit_vs_dc_flux(qubit_freq_sweep, dc_flux_sweep, sig_amp_qubit, fit_order = 2, plot_flag = False)
machine.flux_lines[flux_index].max_frequency_point = Analysis.get_sweept_spot(poly_param).tolist() + 0E1
print(f"sweet spot flux: {machine.flux_lines[flux_index].max_frequency_point:.5f} V")
# Out:
# sweet spot flux: -0.13777 V

# %%
# save the sweep spot flux according to fitted parameter
poly_param = Analysis.exp2D.qubit_vs_dc_flux(qubit_freq_sweep, dc_flux_sweep, sig_amp_qubit, fit_order = 4, plot_flag = True)
machine.qubits[qubit_index].DC_tuning_curve = poly_param.tolist()
machine = Analysis.set_machine(machine)
Analysis.update_analysis_tuning_curve(qubit_index,res_index,flux_index)

# %% [markdown]
# ## 2D qubit spectroscopy vs fast flux

# %%
# set DC voltage to sweet spot, after possible dc flux sweep
machine = Experiment.set_QDAC(qubit_index,res_index,flux_index,machine.flux_lines[flux_index].max_frequency_point)
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### slow version, compiling 1D scans

# %%
# octave calibration
Experiment.octave_calibration(qubit_index,res_index,flux_index,calibration_flag = False)
# Out:
# 2024-01-23 13:24:44,179 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 13:24:44,190 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed

# %%
# try the experiment
# %matplotlib qt
#ff_sweep = np.arange(-0.02,-0.28-1E-4,-0.02)
ff_sweep = np.arange(0,0.4+1E-4,0.05)
qubit_if_sweep = np.arange(-60E6, 60E6 + 1, 1E6)
if True: # first time running this, no AC_tuning_curve
    machine,qubit_freq_sweep,ff_sweep_abs,sig_amp_qubit = Experiment.exp2D.Rabi.qubit_freq_vs_fast_flux_slow(ff_sweep,qubit_if_sweep,
          qubit_index,res_index,flux_index,ff_to_dc_ratio = 4.5, machine = machine, n_avg = 1E3, cd_time = 10E3, pi_amp_rel = 1.0, plot_flag = True)
else: # after the first run 
    machine,qubit_freq_sweep,ff_sweep_abs,sig_amp_qubit = Experiment.exp2D.Rabi.qubit_freq_vs_fast_flux_slow(ff_sweep,qubit_if_sweep,
          qubit_index,res_index,flux_index,ff_to_dc_ratio = None, machine = machine, n_avg = 1E3, cd_time = 10E3, pi_amp_rel = 1.0, plot_flag = True)
# Out:
# 2024-01-23 13:50:03,037 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 13:50:03,043 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates q4 for (LO, IF) = (5.435 GHz, 290.000 MHz)
# 2024-01-23 13:50:08,815 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# 2024-01-23 13:50:40,737 - qm - INFO     - Performing health check.6% (n=5/9) --> elapsed time: 37.69s
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 13:50:40,748 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates q4 for (LO, IF) = (5.174 GHz, 290.000 MHz)
# 2024-01-23 13:50:46,441 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# 2024-01-23 13:51:10,815 - qm - INFO     - Performing health check.8% (n=7/9) --> elapsed time: 67.76s
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 13:51:10,824 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates q4 for (LO, IF) = (4.870 GHz, 290.000 MHz)
# 2024-01-23 13:51:16,480 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# 2024-01-23 13:51:36,092 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 13:51:36,104 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates q4 for (LO, IF) = (4.686 GHz, 290.000 MHz)
# 2024-01-23 13:51:40,889 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# Progress: [##################################################] 100.0% (n=9/9) --> elapsed time: 118.07s
# 2024-01-23 13:52:01,120 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 13:52:01,131 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates q4 for (LO, IF) = (4.487 GHz, 290.000 MHz)
# 2024-01-23 13:52:05,999 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!

# %%
# save the fitted tuning curve
# %matplotlib inline
poly_param = Analysis.exp2D.qubit_vs_fast_flux(qubit_freq_sweep, ff_sweep_abs, sig_amp_qubit, fit_order = 4, plot_flag = True)
machine.qubits[qubit_index].AC_tuning_curve = poly_param.tolist()
machine = Analysis.set_machine(machine)
Analysis.update_analysis_tuning_curve(qubit_index,res_index,flux_index)

# %% [markdown]
# ### fast version, runs blockwise 2D sweeps

# %%
machine = Analysis.get_machine()

# %%
# %matplotlib qt
q_freq_max = np.floor(np.polyval(machine.qubits[qubit_index].AC_tuning_curve, 0.0) * 1E6)
qubit_freq_sweep = np.arange(q_freq_max, 4E9, -4E6)
#qubit_freq_sweep = np.arange(q_freq_max,4E9,-100E6)
qubit_if_sweep = np.arange(-60E6, 60E6 + 1, 0.5E6)
machine,qubit_freq_sweep,ff_sweep_abs,sig_amp_qubit = Experiment.exp2D.Rabi.qubit_freq_vs_fast_flux(qubit_freq_sweep,qubit_if_sweep,
          qubit_index,res_index,flux_index, n_avg = 4E3, cd_time = 10E3, plot_flag = True)
# Out:
# -------------------------------------some fast flux > 0.5V, removed from experiment run
# 2024-01-23 14:03:57,614 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 14:03:57,622 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates q4 for (LO, IF) = (5.424 GHz, 200.000 MHz)
# 2024-01-23 14:04:02,589 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 534.03s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 534.19s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 534.21s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 534.36s
# 2024-01-23 14:22:12,548 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 14:22:12,559 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates q4 for (LO, IF) = (5.224 GHz, 200.000 MHz)
# 2024-01-23 14:22:18,319 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 534.14s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 534.29s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 534.11s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 534.27s
# 2024-01-23 14:40:28,662 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 14:40:28,677 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates q4 for (LO, IF) = (4.624 GHz, 200.000 MHz)
# 2024-01-23 14:40:34,315 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 534.10s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 534.26s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 534.17s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 534.34s
# 2024-01-23 14:58:45,521 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 14:58:45,535 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates q4 for (LO, IF) = (4.424 GHz, 200.000 MHz)
# 2024-01-23 14:58:51,175 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 534.18s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 534.34s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 534.06s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 534.21s
# 2024-01-23 15:17:01,463 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 15:17:01,476 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates q4 for (LO, IF) = (3.824 GHz, 200.000 MHz)
# 2024-01-23 15:17:07,151 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 160.26s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 160.41s
# 2024-01-23 15:20:05,651 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 15:20:05,662 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates q4 for (LO, IF) = (3.624 GHz, 200.000 MHz)
# 2024-01-23 15:20:11,269 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program

# %%
# save the fitted tuning curve
# %matplotlib inline
poly_param = Analysis.exp2D.qubit_vs_fast_flux(qubit_freq_sweep, ff_sweep_abs, sig_amp_qubit, fit_order = 4, plot_flag = True)
machine.qubits[qubit_index].AC_tuning_curve = poly_param.tolist()
#machine.qubits[qubit_index].AC_tuning_curve = [-4245.549395948013,0.0,-6707.594982241495,0.0,6413.009439410573]
machine = Analysis.set_machine(machine)
Analysis.update_analysis_tuning_curve(qubit_index,res_index,flux_index)
# Out:
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!

# %% [markdown]
# # TLS experiments

# %% [markdown]
# ## TLS SWAP spectroscopy

# %%
machine = Analysis.get_machine()
Experiment.octave_calibration(qubit_index,res_index,flux_index,calibration_flag = True, machine = machine)
# Out:
# 2024-01-23 15:32:10,395 - qm - INFO     - Performing health check
# INFO:qm.api.frontend_api:Performing health check
# 2024-01-23 15:32:10,410 - qm - INFO     - Health check passed
# INFO:qm.api.frontend_api:Health check passed
# ------------------------------------- Calibrates r4 for (LO, IF) = (6.277 GHz, -50.000 MHz)
# 2024-01-23 15:32:17,085 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# ------------------------------------- Calibrates q4 for (LO, IF) = (3.874 GHz, -50.000 MHz)
# 2024-01-23 15:32:29,570 - qm - INFO     - Compiling program
# INFO:qm.QuantumMachine:Compiling program
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[91], line 2
#       1 machine = Analysis.get_machine()
# ----> 2 Experiment.octave_calibration(qubit_index,res_index,flux_index,calibration_flag = True, machine = machine)
#
# File ~\QM\QM_UALA\TLS_T1\ExperimentClass.py:191, in ExperimentHandle.octave_calibration(self, qubit_index, res_index, flux_index, machine, log_flag, qubit_only, calibration_flag)
#     189 	Q_off = calibration_parameters[i]["q_offset"]
#     190 	C_mat = calibration_parameters[i]["correction"]
# --> 191 	qm = qmm.open_qm(config)
#     192 	qm.set_output_dc_offset_by_element(machine.resonators[res_index].name, ('I', 'Q'), (I_off, Q_off))
#     193 else:
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\qm\quantum_machines_manager.py:186, in QuantumMachinesManager.open_qm(self, config, close_other_machines, validate_with_protobuf, use_calibration_data, **kwargs)
#     183     logger.warning(f"unused kwargs: {list(kwargs)}, please remove them.")
#     185 if use_calibration_data and self._octave_config is not None and self._octave_config.calibration_db is not None:
# --> 186     load_from_calibration_db(config, self._octave_config.calibration_db)
#     188 qua_config = self._load_config(config, disable_marshmallow_validation=validate_with_protobuf)
#     190 machine_id = self._frontend.open_qm(qua_config, close_other_machines)
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\qm\octave\calibration_db.py:153, in load_from_calibration_db(config, calibration_db)
#     151 i_port = element["mixInputs"]["I"]
#     152 q_port = element["mixInputs"]["Q"]
# --> 153 result = calibration_db.get_or_none(mixer, lo_freq, if_freq)
#     154 if result is not None:
#     155     config["controllers"][i_port[0]]["analog_outputs"][i_port[1]]["offset"] = result.i_offset
#
# File ~\.conda\envs\labber-qm-env\lib\site-packages\qm\octave\calibration_db.py:62, in CalibrationDB.get_or_none(self, mixer, lo_freq, if_freq)
#      60 def get_or_none(self, mixer, lo_freq, if_freq) -> Optional[CalibrationResult]:
#      61     query = Query()
# ---> 62     doc = self._db.get(
#      63         (query.mixer_id == mixer) & (query.lo_frequency == lo_freq) & (query.if_frequency == if_freq)
#      64     )
#      65     if doc is not None:
#      66         return self._doc_to_result(doc)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tinydb\table.py:331, in Table.get(self, cond, doc_id, doc_ids)
#     319     return [
#     320         self.document_class(doc, self.document_id_class(doc_id))
#     321         for doc_id, doc in table.items()
#     322         if doc_id in doc_ids_set
#     323     ]
#     325 elif cond is not None:
#     326     # Find a document specified by a query
#     327     # The trailing underscore in doc_id_ is needed so MyPy
#     328     # doesn't think that `doc_id_` (which is a string) needs
#     329     # to have the same type as `doc_id` which is this function's
#     330     # parameter and is an optional `int`.
# --> 331     for doc_id_, doc in self._read_table().items():
#     332         if cond(doc):
#     333             return self.document_class(
#     334                 doc,
#     335                 self.document_id_class(doc_id_)
#     336             )
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tinydb\table.py:704, in Table._read_table(self)
#     695 """
#     696 Read the table data from the underlying storage.
#     697
#    (...)
#     700 only one document for example.
#     701 """
#     703 # Retrieve the tables from the storage
# --> 704 tables = self._storage.read()
#     706 if tables is None:
#     707     # The database is empty
#     708     return {}
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tinydb\storages.py:124, in JSONStorage.read(self)
#     121 def read(self) -> Optional[Dict[str, Dict[str, Any]]]:
#     122     # Get the file size by moving the cursor to the file end and reading
#     123     # its location
# --> 124     self._handle.seek(0, os.SEEK_END)
#     125     size = self._handle.tell()
#     127     if not size:
#     128         # File is empty, so we return ``None`` so TinyDB can properly
#     129         # initialize the database
#
# File ~\.conda\envs\labber-qm-env\lib\codecs.py:214, in IncrementalEncoder.setstate(self, state)
#     209     """
#     210     Return the current state of the encoder.
#     211     """
#     212     return 0
# --> 214 def setstate(self, state):
#     215     """
#     216     Set the current state of the encoder. state must have been
#     217     returned by getstate().
#     218     """
#
# KeyboardInterrupt:

# %% [markdown]
# ### coarse, no baking

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(16,120 + 0.1,4)
ff_sweep_abs = np.arange(0.25,0.4,0.001)
machine, ff_sweep_abs, tau_sweep_abs, sig_amp = Experiment.exp2D.SWAP.swap_coarse(tau_sweep_abs, ff_sweep_abs, qubit_index, res_index, flux_index, 
                      n_avg = 1E3, cd_time = 40E3, simulate_flag=False, simulation_len=10_000, plot_flag=True, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=1000/1000.0) --> elapsed time: 167.24s

# %% [markdown]
# ### fine, with baking

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(4,120,1)
ff_sweep_abs = np.arange(0.23,0.35+1E-4,0.001)
machine, ff_sweep_abs, tau_sweep_abs, sig_amp = Experiment.exp2D.SWAP.swap_fine(tau_sweep_abs, ff_sweep_abs, qubit_index, res_index, flux_index, 
                      n_avg = 4E3, cd_time = 100E3, simulate_flag=False, simulation_len=10_000, plot_flag=True, machine = machine)
# Out:
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 11266.38s
# Execution stopped by user!

# %%
machine.flux_lines[flux_index].iswap.length = [13,36]
machine.flux_lines[flux_index].iswap.level = [0.129,0.316]
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### estiguess of the TLS freq., based on SWAP flux

# %%
machine = Analysis.get_machine()

# %%
freq_tls = np.polyval(machine.qubits[qubit_index].AC_tuning_curve,machine.flux_lines[flux_index].iswap.level)
for f_tmp in freq_tls:
    machine.qubits[qubit_index].f_tls.append(np.floor(f_tmp*1E6))
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## TLS T1

# %%
print(freq_tls)
# Out:
# [5628.23678966 5106.76562868]

# %%
TLS_index = 1

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(100,15E3+1,200)
#tau_sweep_abs = np.logspace(100,2000E3,50,endpoint=True)
machine, tau_sweep_abs, sig_amp = Experiment.exp1D.T1.TLS_T1(tau_sweep_abs, qubit_index, res_index, flux_index, TLS_index,
                   n_avg = 4E3, cd_time_qubit = 10E3, cd_time_TLS = 300E3, simulate_flag = False, simulation_len = 15_000, plot_flag = True)
# Out:
# Execution stopped by user!##                                 ] 34.9% (n=1397/4000.0) --> elapsed time: 34.22s
# Progress: [#################                                 ] 35.1% (n=1406/4000.0) --> elapsed time: 34.52s

# %%
# %matplotlib inline
TLS_T1 = Analysis.exp1D.T1(tau_sweep_abs,sig_amp,method = "exp")
# Out:
# Qubit T1 [us]: 1.643969508671383
