# %%
from qm.qua import *
from qm.QuantumMachinesManager import QuantumMachinesManager
from qm import SimulationConfig, LoopbackInterface
from configuration import *
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
from qualang_tools.loops import from_array
import qdac
import random
import math
import time
# %matplotlib qt

# Start to save data
import datetime 
import os
import pandas as pd 

now = datetime.datetime.now()
year = now.strftime("%Y")
month = now.strftime("%m")
day = now.strftime("%d")
hour = now.strftime("%H")
minute = now.strftime("%M")
second  = now.strftime("%S")

tPath = os.path.join(r'Z:\LabberData_DF5\QM_Data_DF5',year,month,'Data_'+month+day)
if not os.path.exists(tPath):
   os.makedirs(tPath)
exp_name = 'RR_spec_wFlux'
qubit_name = 'Q2'

f_str =exp_name + '_'+ qubit_name +'_'+ hour+ '_' + minute +'_' + second
f_name= f_str+'.csv'
j_name = f_str + '_state.json'
p_name= f_str+'.png'

# End to save data


#########################################
# Set-up the machine and get the config #
#########################################
machine = QuAM("quam_state.json", flat_data=False)
#machine.resonators[0].f_readout+=1.68e6
# machine.resonators[0].readout_pulse_amp=0.27
config = build_config(machine)

##############################
# Program-specific variables #
##############################

n_avg = 500  # Number of averaging loops

cooldown_time = 10_000  # Resonator cooldown time 
flux_settle_time = 250  # Flux settle time 

flux_pts = 250

#dcs = np.linspace(-0.49, 0.49, flux_pts)
dcs = np.arange(-9,9,0.1)
dfs = np.arange(-12.5e6, 7.5e6, 0.05e6)

number_of_qubits = 1
resonators_list = [i for i in range(number_of_qubits)]
res_if_list = [machine.resonators[i].f_readout - machine.resonators[i].lo for i in range(number_of_qubits)]

qubit_index = 0

with qdac.qdac('COM3') as q:
    for idx_dc, _ in enumerate(dcs):
        dc = dcs[idx_dc]
        q.setDCVoltage(channel=6, volts=dc)

    ###################
    # The QUA program #
    ###################
        time.sleep(1)
        
        with program() as resonator_spec_2D:
            n = declare(int)  # Averaging index
            df = declare(int)  # Resonator frequency
            # dc = declare(fixed)  # flux dc level|
            I = declare(fixed)
            Q = declare(fixed)
            I_st = declare_stream()
            Q_st = declare_stream()
            n_st = declare_stream()
            #wait(flux_settle_time , machine.resonators[qubit_index].name, machine.qubits[qubit_index].name)
            
            with for_(n, 0, n < n_avg, n + 1):
                with for_(*from_array(df, dfs)):
                    # Update the resonator frequency
                    update_frequency(machine.resonators[qubit_index].name, df + res_if_list[qubit_index])
                    # with for_(*from_array(dc, dcs)):
                        # Flux sweeping
                        # set_dc_offset(machine.flux_lines[qubit_index].name, "single", dc)
                        # wait(flux_settle_time * u.ns, machine.resonators[qubit_index].name, machine.qubits[qubit_index].name)
                        # Measure the resonator
                    measure(
                        "readout",
                        machine.resonators[qubit_index].name,
                        None,
                        dual_demod.full("cos", "out1", "sin", "out2", I),
                        dual_demod.full("minus_sin", "out1", "cos", "out2", Q),
                    )
                    # Wait for the resonator to cooldown
                    wait(cooldown_time * u.ns, machine.resonators[qubit_index].name)
                    # Save data to the stream processing
                    save(I, I_st)
                    save(Q, Q_st)
                save(n, n_st)
        
            with stream_processing():
                # I_st.buffer(len(dcs)).buffer(len(dfs)).average().save("I")
                # Q_st.buffer(len(dcs)).buffer(len(dfs)).average().save("Q")
                I_st.buffer(len(dfs)).average().save("I")
                Q_st.buffer(len(dfs)).average().save("Q")
                n_st.save("iteration")


        #####################################
        #  Open Communication with the QOP  #
        #####################################
        qmm = QuantumMachinesManager(machine.network.qop_ip, cluster_name=machine.network.cluster_name, octave=octave_config)
        
        simulation = False
        
        qm = qmm.open_qm(config)
        job = qm.execute(resonator_spec_2D)
        # Get results from QUA program
        results = fetching_tool(job, data_list=["I", "Q", "iteration"], mode="live")

        fig = plt.figure(1)
        plt.rcParams['figure.figsize'] = [12, 8]
        interrupt_on_close(fig, job)  #  Interrupts the job when closing the figure

        # Progress bar
        progress_counter(idx_dc, len(dcs))
            
        while results.is_processing():
            I_tmp, Q_tmp, iteration_tmp = results.fetch_all()
            I_tmp = u.demod2volts(I_tmp, machine.resonators[qubit_index].readout_pulse_length)
            Q_tmp = u.demod2volts(Q_tmp, machine.resonators[qubit_index].readout_pulse_length)

    
            # Live plotting
            plt.subplot(211)
            plt.cla()
            plt.title("Resonator spectroscopy amplitude")
            plt.plot((dfs ) / u.MHz, np.sqrt(I_tmp**2 + Q_tmp**2), ".")
            plt.xlabel("Frequency [MHz]")
            plt.ylabel(r"$\sqrt{I^2 + Q^2}$ [a.u.]")
            plt.subplot(212)
            plt.cla()
            # detrend removes the linear increase of phase
            phase = signal.detrend(np.unwrap(np.angle(I_tmp + 1j * Q_tmp)))
            plt.title("Resonator spectroscopy phase")
            plt.plot((dfs ) / u.MHz, phase, ".")
            plt.xlabel("Frequency [MHz]")
            plt.ylabel("Phase [rad]")
            plt.pause(0.1)
            
        if idx_dc == 0:
            I_2D = I_tmp
            Q_2D = Q_tmp
        else:
            I_2D = np.hstack([I_2D, I_tmp])
            Q_2D = np.hstack([Q_2D, Q_tmp])

I_2D = np.reshape(I_2D, (len(dcs), len(I_tmp)))
Q_2D = np.reshape(Q_2D, (len(dcs), len(Q_tmp)))
# 2D plot
fig = plt.figure()
plt.rcParams['figure.figsize'] = [12, 8]
# 2D spectroscopy plot
plt.subplot(211)
plt.cla()
plt.title("Resonator spectroscopy tuning curve")
plt.pcolor(dfs/ u.MHz, dcs, np.sqrt(I_2D**2 + Q_2D**2),cmap="seismic")
plt.xlabel("DC flux level [V]")
plt.ylabel("Frequency [MHz]")
plt.colorbar()
#plt.axvline(x=0)
plt.subplot(212)
plt.cla()
plt.title("Resonator spectroscopy phase")
phase = signal.detrend(np.unwrap(np.angle(I_2D + 1j * Q_2D)))
plt.pcolor(dfs/ u.MHz, dcs, phase ,cmap="seismic")
plt.xlabel("DC flux level [V]")
plt.ylabel("Frequency [MHz]")
plt.colorbar()
#plt.axvline(x=0)
#plt.pause(0.1)
plt.tight_layout()
# Out:
# 2023-08-15 15:29:25,229 - qm - INFO     - Performing health check
# 2023-08-15 15:29:25,239 - qm - INFO     - Health check passed
# 2023-08-15 15:29:25,732 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:29:25,847 - qm - INFO     - Executing program
# 2023-08-15 15:29:29,863 - qm - INFO     - Performing health check6% (n=1/180)
# 2023-08-15 15:29:29,872 - qm - INFO     - Health check passed
# 2023-08-15 15:29:30,373 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:29:30,793 - qm - INFO     - Executing program
# 2023-08-15 15:29:34,804 - qm - INFO     - Performing health check1% (n=2/180)
# 2023-08-15 15:29:34,814 - qm - INFO     - Health check passed
# 2023-08-15 15:29:35,354 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:29:35,511 - qm - INFO     - Executing program
# 2023-08-15 15:29:39,457 - qm - INFO     - Performing health check7% (n=3/180)
# 2023-08-15 15:29:39,467 - qm - INFO     - Health check passed
# 2023-08-15 15:29:40,433 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:29:40,595 - qm - INFO     - Executing program
# 2023-08-15 15:29:44,614 - qm - INFO     - Performing health check2% (n=4/180)
# 2023-08-15 15:29:44,624 - qm - INFO     - Health check passed
# 2023-08-15 15:29:45,739 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:29:45,886 - qm - INFO     - Executing program
# 2023-08-15 15:29:50,173 - qm - INFO     - Performing health check8% (n=5/180)
# 2023-08-15 15:29:50,183 - qm - INFO     - Health check passed
# 2023-08-15 15:29:51,017 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:29:51,133 - qm - INFO     - Executing program
# 2023-08-15 15:29:55,110 - qm - INFO     - Performing health check3% (n=6/180)
# 2023-08-15 15:29:55,120 - qm - INFO     - Health check passed
# 2023-08-15 15:29:55,822 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:29:55,960 - qm - INFO     - Executing program
# 2023-08-15 15:29:59,942 - qm - INFO     - Performing health check9% (n=7/180)
# 2023-08-15 15:29:59,951 - qm - INFO     - Health check passed
# 2023-08-15 15:30:00,457 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:30:00,614 - qm - INFO     - Executing program
# 2023-08-15 15:30:04,512 - qm - INFO     - Performing health check4% (n=8/180)
# 2023-08-15 15:30:04,518 - qm - INFO     - Health check passed
# 2023-08-15 15:30:05,154 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:30:05,268 - qm - INFO     - Executing program
# 2023-08-15 15:30:09,342 - qm - INFO     - Performing health check0% (n=9/180)
# 2023-08-15 15:30:09,352 - qm - INFO     - Health check passed
# 2023-08-15 15:30:10,231 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:30:10,368 - qm - INFO     - Executing program
# 2023-08-15 15:30:14,476 - qm - INFO     - Performing health check6% (n=10/180)
# 2023-08-15 15:30:14,486 - qm - INFO     - Health check passed
# 2023-08-15 15:30:15,543 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:30:15,685 - qm - INFO     - Executing program
# 2023-08-15 15:30:19,770 - qm - INFO     - Performing health check1% (n=11/180)
# 2023-08-15 15:30:19,780 - qm - INFO     - Health check passed
# 2023-08-15 15:30:20,819 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:30:20,967 - qm - INFO     - Executing program
# 2023-08-15 15:30:25,026 - qm - INFO     - Performing health check7% (n=12/180)
# 2023-08-15 15:30:25,037 - qm - INFO     - Health check passed
# 2023-08-15 15:30:26,127 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:30:26,265 - qm - INFO     - Executing program
# 2023-08-15 15:30:30,421 - qm - INFO     - Performing health check2% (n=13/180)
# 2023-08-15 15:30:30,431 - qm - INFO     - Health check passed
# 2023-08-15 15:30:31,422 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:30:31,561 - qm - INFO     - Executing program
# 2023-08-15 15:30:35,642 - qm - INFO     - Performing health check8% (n=14/180)
# 2023-08-15 15:30:35,652 - qm - INFO     - Health check passed
# 2023-08-15 15:30:36,686 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:30:36,835 - qm - INFO     - Executing program
# 2023-08-15 15:30:40,881 - qm - INFO     - Performing health check3% (n=15/180)
# 2023-08-15 15:30:40,891 - qm - INFO     - Health check passed
# 2023-08-15 15:30:41,979 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:30:42,137 - qm - INFO     - Executing program
# 2023-08-15 15:30:46,144 - qm - INFO     - Performing health check9% (n=16/180)
# 2023-08-15 15:30:46,154 - qm - INFO     - Health check passed
# 2023-08-15 15:30:47,277 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:30:47,444 - qm - INFO     - Executing program
# 2023-08-15 15:30:51,469 - qm - INFO     - Performing health check4% (n=17/180)
# 2023-08-15 15:30:51,479 - qm - INFO     - Health check passed
# 2023-08-15 15:30:52,553 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:30:52,719 - qm - INFO     - Executing program
# 2023-08-15 15:30:56,951 - qm - INFO     - Performing health check.0% (n=18/180)
# 2023-08-15 15:30:56,960 - qm - INFO     - Health check passed
# 2023-08-15 15:30:57,831 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:30:57,985 - qm - INFO     - Executing program
# 2023-08-15 15:31:02,050 - qm - INFO     - Performing health check.6% (n=19/180)
# 2023-08-15 15:31:02,059 - qm - INFO     - Health check passed
# 2023-08-15 15:31:03,147 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:31:03,295 - qm - INFO     - Executing program
# 2023-08-15 15:31:07,323 - qm - INFO     - Performing health check.1% (n=20/180)
# 2023-08-15 15:31:07,333 - qm - INFO     - Health check passed
# 2023-08-15 15:31:08,440 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:31:08,586 - qm - INFO     - Executing program
# 2023-08-15 15:31:12,549 - qm - INFO     - Performing health check.7% (n=21/180)
# 2023-08-15 15:31:12,559 - qm - INFO     - Health check passed
# 2023-08-15 15:31:13,289 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:31:13,473 - qm - INFO     - Executing program
# 2023-08-15 15:31:17,786 - qm - INFO     - Performing health check.2% (n=22/180)
# 2023-08-15 15:31:17,795 - qm - INFO     - Health check passed
# 2023-08-15 15:31:18,519 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:31:18,692 - qm - INFO     - Executing program
# 2023-08-15 15:31:22,526 - qm - INFO     - Performing health check.8% (n=23/180)
# 2023-08-15 15:31:22,536 - qm - INFO     - Health check passed
# 2023-08-15 15:31:23,037 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:31:23,217 - qm - INFO     - Executing program
# 2023-08-15 15:31:27,185 - qm - INFO     - Performing health check.3% (n=24/180)
# 2023-08-15 15:31:27,194 - qm - INFO     - Health check passed
# 2023-08-15 15:31:27,835 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:31:27,978 - qm - INFO     - Executing program
# 2023-08-15 15:31:31,844 - qm - INFO     - Performing health check.9% (n=25/180)
# 2023-08-15 15:31:31,853 - qm - INFO     - Health check passed
# 2023-08-15 15:31:32,916 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:31:33,065 - qm - INFO     - Executing program
# 2023-08-15 15:31:37,158 - qm - INFO     - Performing health check.4% (n=26/180)
# 2023-08-15 15:31:37,168 - qm - INFO     - Health check passed
# 2023-08-15 15:31:38,240 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:31:38,355 - qm - INFO     - Executing program
# 2023-08-15 15:31:42,490 - qm - INFO     - Performing health check.0% (n=27/180)
# 2023-08-15 15:31:42,500 - qm - INFO     - Health check passed
# 2023-08-15 15:31:43,542 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:31:43,697 - qm - INFO     - Executing program
# 2023-08-15 15:31:47,787 - qm - INFO     - Performing health check.6% (n=28/180)
# 2023-08-15 15:31:47,797 - qm - INFO     - Health check passed
# 2023-08-15 15:31:48,814 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:31:48,959 - qm - INFO     - Executing program
# 2023-08-15 15:31:53,177 - qm - INFO     - Performing health check.1% (n=29/180)
# 2023-08-15 15:31:53,188 - qm - INFO     - Health check passed
# 2023-08-15 15:31:54,110 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:31:54,264 - qm - INFO     - Executing program
# 2023-08-15 15:31:58,407 - qm - INFO     - Performing health check.7% (n=30/180)
# 2023-08-15 15:31:58,416 - qm - INFO     - Health check passed
# 2023-08-15 15:31:59,388 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:31:59,563 - qm - INFO     - Executing program
# 2023-08-15 15:32:03,542 - qm - INFO     - Performing health check.2% (n=31/180)
# 2023-08-15 15:32:03,552 - qm - INFO     - Health check passed
# 2023-08-15 15:32:04,271 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:32:04,416 - qm - INFO     - Executing program
# 2023-08-15 15:32:08,301 - qm - INFO     - Performing health check.8% (n=32/180)
# 2023-08-15 15:32:08,311 - qm - INFO     - Health check passed
# 2023-08-15 15:32:08,824 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:32:08,953 - qm - INFO     - Executing program
# 2023-08-15 15:32:12,920 - qm - INFO     - Performing health check.3% (n=33/180)
# 2023-08-15 15:32:12,930 - qm - INFO     - Health check passed
# 2023-08-15 15:32:13,587 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:32:13,727 - qm - INFO     - Executing program
# 2023-08-15 15:32:17,663 - qm - INFO     - Performing health check.9% (n=34/180)
# 2023-08-15 15:32:17,673 - qm - INFO     - Health check passed
# 2023-08-15 15:32:18,656 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:32:18,811 - qm - INFO     - Executing program
# 2023-08-15 15:32:22,770 - qm - INFO     - Performing health check.4% (n=35/180)
# 2023-08-15 15:32:22,780 - qm - INFO     - Health check passed
# 2023-08-15 15:32:23,494 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:32:23,667 - qm - INFO     - Executing program
# 2023-08-15 15:32:27,587 - qm - INFO     - Performing health check.0% (n=36/180)
# 2023-08-15 15:32:27,597 - qm - INFO     - Health check passed
# 2023-08-15 15:32:28,081 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:32:28,227 - qm - INFO     - Executing program
# 2023-08-15 15:32:32,254 - qm - INFO     - Performing health check.6% (n=37/180)
# 2023-08-15 15:32:32,264 - qm - INFO     - Health check passed
# 2023-08-15 15:32:32,799 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:32:32,947 - qm - INFO     - Executing program
# 2023-08-15 15:32:36,898 - qm - INFO     - Performing health check.1% (n=38/180)
# 2023-08-15 15:32:36,906 - qm - INFO     - Health check passed
# 2023-08-15 15:32:37,894 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:32:38,009 - qm - INFO     - Executing program
# 2023-08-15 15:32:42,174 - qm - INFO     - Performing health check.7% (n=39/180)
# 2023-08-15 15:32:42,184 - qm - INFO     - Health check passed
# 2023-08-15 15:32:43,185 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:32:43,330 - qm - INFO     - Executing program
# 2023-08-15 15:32:47,318 - qm - INFO     - Performing health check.2% (n=40/180)
# 2023-08-15 15:32:47,327 - qm - INFO     - Health check passed
# 2023-08-15 15:32:48,047 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:32:48,213 - qm - INFO     - Executing program
# 2023-08-15 15:32:52,141 - qm - INFO     - Performing health check.8% (n=41/180)
# 2023-08-15 15:32:52,150 - qm - INFO     - Health check passed
# 2023-08-15 15:32:52,694 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:32:52,838 - qm - INFO     - Executing program
# 2023-08-15 15:32:56,841 - qm - INFO     - Performing health check.3% (n=42/180)
# 2023-08-15 15:32:56,851 - qm - INFO     - Health check passed
# 2023-08-15 15:32:57,349 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:32:57,504 - qm - INFO     - Executing program
# 2023-08-15 15:33:01,483 - qm - INFO     - Performing health check.9% (n=43/180)
# 2023-08-15 15:33:01,493 - qm - INFO     - Health check passed
# 2023-08-15 15:33:02,451 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:33:02,575 - qm - INFO     - Executing program
# 2023-08-15 15:33:06,559 - qm - INFO     - Performing health check.4% (n=44/180)
# 2023-08-15 15:33:06,574 - qm - INFO     - Health check passed
# 2023-08-15 15:33:07,278 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:33:07,421 - qm - INFO     - Executing program
# 2023-08-15 15:33:11,340 - qm - INFO     - Performing health check.0% (n=45/180)
# 2023-08-15 15:33:11,350 - qm - INFO     - Health check passed
# 2023-08-15 15:33:11,846 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:33:11,991 - qm - INFO     - Executing program
# 2023-08-15 15:33:16,017 - qm - INFO     - Performing health check.6% (n=46/180)
# 2023-08-15 15:33:16,027 - qm - INFO     - Health check passed
# 2023-08-15 15:33:16,576 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:33:16,694 - qm - INFO     - Executing program
# 2023-08-15 15:33:20,655 - qm - INFO     - Performing health check.1% (n=47/180)
# 2023-08-15 15:33:20,664 - qm - INFO     - Health check passed
# 2023-08-15 15:33:21,679 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:33:21,822 - qm - INFO     - Executing program
# 2023-08-15 15:33:25,918 - qm - INFO     - Performing health check.7% (n=48/180)
# 2023-08-15 15:33:25,928 - qm - INFO     - Health check passed
# 2023-08-15 15:33:26,980 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:33:27,127 - qm - INFO     - Executing program
# 2023-08-15 15:33:31,273 - qm - INFO     - Performing health check.2% (n=49/180)
# 2023-08-15 15:33:31,283 - qm - INFO     - Health check passed
# 2023-08-15 15:33:32,276 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:33:32,416 - qm - INFO     - Executing program
# 2023-08-15 15:33:36,481 - qm - INFO     - Performing health check.8% (n=50/180)
# 2023-08-15 15:33:36,490 - qm - INFO     - Health check passed
# 2023-08-15 15:33:37,579 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:33:37,695 - qm - INFO     - Executing program
# 2023-08-15 15:33:41,760 - qm - INFO     - Performing health check.3% (n=51/180)
# 2023-08-15 15:33:41,770 - qm - INFO     - Health check passed
# 2023-08-15 15:33:43,090 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:33:43,248 - qm - INFO     - Executing program
# 2023-08-15 15:33:47,293 - qm - INFO     - Performing health check.9% (n=52/180)
# 2023-08-15 15:33:47,303 - qm - INFO     - Health check passed
# 2023-08-15 15:33:48,239 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:33:48,408 - qm - INFO     - Executing program
# 2023-08-15 15:33:52,453 - qm - INFO     - Performing health check.4% (n=53/180)
# 2023-08-15 15:33:52,463 - qm - INFO     - Health check passed
# 2023-08-15 15:33:53,410 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:33:53,557 - qm - INFO     - Executing program
# 2023-08-15 15:33:57,565 - qm - INFO     - Performing health check.0% (n=54/180)
# 2023-08-15 15:33:57,575 - qm - INFO     - Health check passed
# 2023-08-15 15:33:58,495 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:33:58,644 - qm - INFO     - Executing program
# 2023-08-15 15:34:02,858 - qm - INFO     - Performing health check.6% (n=55/180)
# 2023-08-15 15:34:02,869 - qm - INFO     - Health check passed
# 2023-08-15 15:34:03,786 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:34:03,961 - qm - INFO     - Executing program
# 2023-08-15 15:34:07,982 - qm - INFO     - Performing health check.1% (n=56/180)
# 2023-08-15 15:34:07,992 - qm - INFO     - Health check passed
# 2023-08-15 15:34:09,087 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:34:09,234 - qm - INFO     - Executing program
# 2023-08-15 15:34:13,297 - qm - INFO     - Performing health check.7% (n=57/180)
# 2023-08-15 15:34:13,304 - qm - INFO     - Health check passed
# 2023-08-15 15:34:14,391 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:34:14,531 - qm - INFO     - Executing program
# 2023-08-15 15:34:18,617 - qm - INFO     - Performing health check.2% (n=58/180)
# 2023-08-15 15:34:18,627 - qm - INFO     - Health check passed
# 2023-08-15 15:34:19,670 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:34:19,821 - qm - INFO     - Executing program
# 2023-08-15 15:34:23,964 - qm - INFO     - Performing health check.8% (n=59/180)
# 2023-08-15 15:34:23,974 - qm - INFO     - Health check passed
# 2023-08-15 15:34:24,973 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:34:25,105 - qm - INFO     - Executing program
# 2023-08-15 15:34:29,209 - qm - INFO     - Performing health check.3% (n=60/180)
# 2023-08-15 15:34:29,223 - qm - INFO     - Health check passed
# 2023-08-15 15:34:30,247 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:34:30,385 - qm - INFO     - Executing program
# 2023-08-15 15:34:34,500 - qm - INFO     - Performing health check.9% (n=61/180)
# 2023-08-15 15:34:34,511 - qm - INFO     - Health check passed
# 2023-08-15 15:34:35,542 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:34:35,681 - qm - INFO     - Executing program
# 2023-08-15 15:34:39,807 - qm - INFO     - Performing health check.4% (n=62/180)
# 2023-08-15 15:34:39,817 - qm - INFO     - Health check passed
# 2023-08-15 15:34:40,826 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:34:40,978 - qm - INFO     - Executing program
# 2023-08-15 15:34:45,004 - qm - INFO     - Performing health check.0% (n=63/180)
# 2023-08-15 15:34:45,014 - qm - INFO     - Health check passed
# 2023-08-15 15:34:46,114 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:34:46,300 - qm - INFO     - Executing program
# 2023-08-15 15:34:50,375 - qm - INFO     - Performing health check.6% (n=64/180)
# 2023-08-15 15:34:50,385 - qm - INFO     - Health check passed
# 2023-08-15 15:34:51,388 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:34:51,529 - qm - INFO     - Executing program
# 2023-08-15 15:34:55,609 - qm - INFO     - Performing health check.1% (n=65/180)
# 2023-08-15 15:34:55,619 - qm - INFO     - Health check passed
# 2023-08-15 15:34:56,691 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:34:56,844 - qm - INFO     - Executing program
# 2023-08-15 15:35:00,988 - qm - INFO     - Performing health check.7% (n=66/180)
# 2023-08-15 15:35:00,998 - qm - INFO     - Health check passed
# 2023-08-15 15:35:02,012 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:35:02,168 - qm - INFO     - Executing program
# 2023-08-15 15:35:06,102 - qm - INFO     - Performing health check.2% (n=67/180)
# 2023-08-15 15:35:06,112 - qm - INFO     - Health check passed
# 2023-08-15 15:35:07,275 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:35:07,419 - qm - INFO     - Executing program
# 2023-08-15 15:35:11,427 - qm - INFO     - Performing health check.8% (n=68/180)
# 2023-08-15 15:35:11,437 - qm - INFO     - Health check passed
# 2023-08-15 15:35:12,131 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:35:12,280 - qm - INFO     - Executing program
# 2023-08-15 15:35:16,225 - qm - INFO     - Performing health check.3% (n=69/180)
# 2023-08-15 15:35:16,235 - qm - INFO     - Health check passed
# 2023-08-15 15:35:16,768 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:35:16,909 - qm - INFO     - Executing program
# 2023-08-15 15:35:20,904 - qm - INFO     - Performing health check.9% (n=70/180)
# 2023-08-15 15:35:20,914 - qm - INFO     - Health check passed
# 2023-08-15 15:35:21,437 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:35:21,622 - qm - INFO     - Executing program
# 2023-08-15 15:35:25,548 - qm - INFO     - Performing health check.4% (n=71/180)
# 2023-08-15 15:35:25,558 - qm - INFO     - Health check passed
# 2023-08-15 15:35:26,537 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:35:26,694 - qm - INFO     - Executing program
# 2023-08-15 15:35:30,733 - qm - INFO     - Performing health check.0% (n=72/180)
# 2023-08-15 15:35:30,743 - qm - INFO     - Health check passed
# 2023-08-15 15:35:31,818 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:35:31,962 - qm - INFO     - Executing program
# 2023-08-15 15:35:35,969 - qm - INFO     - Performing health check.6% (n=73/180)
# 2023-08-15 15:35:35,980 - qm - INFO     - Health check passed
# 2023-08-15 15:35:36,707 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:35:36,868 - qm - INFO     - Executing program
# 2023-08-15 15:35:41,152 - qm - INFO     - Performing health check.1% (n=74/180)
# 2023-08-15 15:35:41,183 - qm - INFO     - Health check passed
# 2023-08-15 15:35:41,946 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:35:42,100 - qm - INFO     - Executing program
# 2023-08-15 15:35:45,949 - qm - INFO     - Performing health check.7% (n=75/180)
# 2023-08-15 15:35:45,958 - qm - INFO     - Health check passed
# 2023-08-15 15:35:46,485 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:35:46,637 - qm - INFO     - Executing program
# 2023-08-15 15:35:50,687 - qm - INFO     - Performing health check.2% (n=76/180)
# 2023-08-15 15:35:50,698 - qm - INFO     - Health check passed
# 2023-08-15 15:35:51,233 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:35:51,389 - qm - INFO     - Executing program
# 2023-08-15 15:35:55,379 - qm - INFO     - Performing health check.8% (n=77/180)
# 2023-08-15 15:35:55,388 - qm - INFO     - Health check passed
# 2023-08-15 15:35:56,406 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:35:56,550 - qm - INFO     - Executing program
# 2023-08-15 15:36:00,554 - qm - INFO     - Performing health check.3% (n=78/180)
# 2023-08-15 15:36:00,564 - qm - INFO     - Health check passed
# 2023-08-15 15:36:01,507 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:36:01,664 - qm - INFO     - Executing program
# 2023-08-15 15:36:05,693 - qm - INFO     - Performing health check.9% (n=79/180)
# 2023-08-15 15:36:05,703 - qm - INFO     - Health check passed
# 2023-08-15 15:36:06,792 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:36:06,918 - qm - INFO     - Executing program
# 2023-08-15 15:36:10,982 - qm - INFO     - Performing health check.4% (n=80/180)
# 2023-08-15 15:36:10,992 - qm - INFO     - Health check passed
# 2023-08-15 15:36:12,087 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:36:12,243 - qm - INFO     - Executing program
# 2023-08-15 15:36:16,358 - qm - INFO     - Performing health check.0% (n=81/180)
# 2023-08-15 15:36:16,369 - qm - INFO     - Health check passed
# 2023-08-15 15:36:17,375 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:36:17,552 - qm - INFO     - Executing program
# 2023-08-15 15:36:21,593 - qm - INFO     - Performing health check.6% (n=82/180)
# 2023-08-15 15:36:21,603 - qm - INFO     - Health check passed
# 2023-08-15 15:36:22,660 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:36:22,826 - qm - INFO     - Executing program
# 2023-08-15 15:36:26,963 - qm - INFO     - Performing health check.1% (n=83/180)
# 2023-08-15 15:36:26,971 - qm - INFO     - Health check passed
# 2023-08-15 15:36:27,952 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:36:28,097 - qm - INFO     - Executing program
# 2023-08-15 15:36:32,146 - qm - INFO     - Performing health check.7% (n=84/180)
# 2023-08-15 15:36:32,156 - qm - INFO     - Health check passed
# 2023-08-15 15:36:33,482 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:36:33,644 - qm - INFO     - Executing program
# 2023-08-15 15:36:37,719 - qm - INFO     - Performing health check.2% (n=85/180)
# 2023-08-15 15:36:37,727 - qm - INFO     - Health check passed
# 2023-08-15 15:36:38,618 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:36:38,775 - qm - INFO     - Executing program
# 2023-08-15 15:36:42,818 - qm - INFO     - Performing health check.8% (n=86/180)
# 2023-08-15 15:36:42,828 - qm - INFO     - Health check passed
# 2023-08-15 15:36:43,705 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:36:43,853 - qm - INFO     - Executing program
# 2023-08-15 15:36:47,826 - qm - INFO     - Performing health check.3% (n=87/180)
# 2023-08-15 15:36:47,835 - qm - INFO     - Health check passed
# 2023-08-15 15:36:48,529 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:36:48,679 - qm - INFO     - Executing program
# 2023-08-15 15:36:52,937 - qm - INFO     - Performing health check.9% (n=88/180)
# 2023-08-15 15:36:52,947 - qm - INFO     - Health check passed
# 2023-08-15 15:36:53,443 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:36:53,614 - qm - INFO     - Executing program
# 2023-08-15 15:36:57,515 - qm - INFO     - Performing health check.4% (n=89/180)
# 2023-08-15 15:36:57,525 - qm - INFO     - Health check passed
# 2023-08-15 15:36:58,033 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:36:58,198 - qm - INFO     - Executing program
# 2023-08-15 15:37:02,303 - qm - INFO     - Performing health check.0% (n=90/180)
# 2023-08-15 15:37:02,313 - qm - INFO     - Health check passed
# 2023-08-15 15:37:03,033 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:37:03,172 - qm - INFO     - Executing program
# 2023-08-15 15:37:07,145 - qm - INFO     - Performing health check.6% (n=91/180)
# 2023-08-15 15:37:07,155 - qm - INFO     - Health check passed
# 2023-08-15 15:37:08,145 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:37:08,337 - qm - INFO     - Executing program
# 2023-08-15 15:37:12,377 - qm - INFO     - Performing health check.1% (n=92/180)
# 2023-08-15 15:37:12,387 - qm - INFO     - Health check passed
# 2023-08-15 15:37:13,399 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:37:13,578 - qm - INFO     - Executing program
# 2023-08-15 15:37:17,606 - qm - INFO     - Performing health check.7% (n=93/180)
# 2023-08-15 15:37:17,616 - qm - INFO     - Health check passed
# 2023-08-15 15:37:18,715 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:37:18,858 - qm - INFO     - Executing program
# 2023-08-15 15:37:22,956 - qm - INFO     - Performing health check.2% (n=94/180)
# 2023-08-15 15:37:22,968 - qm - INFO     - Health check passed
# 2023-08-15 15:37:23,998 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:37:24,174 - qm - INFO     - Executing program
# 2023-08-15 15:37:28,171 - qm - INFO     - Performing health check.8% (n=95/180)
# 2023-08-15 15:37:28,181 - qm - INFO     - Health check passed
# 2023-08-15 15:37:28,869 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:37:28,991 - qm - INFO     - Executing program
# 2023-08-15 15:37:33,029 - qm - INFO     - Performing health check.3% (n=96/180)
# 2023-08-15 15:37:33,039 - qm - INFO     - Health check passed
# 2023-08-15 15:37:33,556 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:37:33,691 - qm - INFO     - Executing program
# 2023-08-15 15:37:37,731 - qm - INFO     - Performing health check.9% (n=97/180)
# 2023-08-15 15:37:37,741 - qm - INFO     - Health check passed
# 2023-08-15 15:37:38,238 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:37:38,377 - qm - INFO     - Executing program
# 2023-08-15 15:37:42,280 - qm - INFO     - Performing health check.4% (n=98/180)
# 2023-08-15 15:37:42,290 - qm - INFO     - Health check passed
# 2023-08-15 15:37:43,281 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:37:43,404 - qm - INFO     - Executing program
# 2023-08-15 15:37:47,484 - qm - INFO     - Performing health check.0% (n=99/180)
# 2023-08-15 15:37:47,494 - qm - INFO     - Health check passed
# 2023-08-15 15:37:48,571 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:37:48,735 - qm - INFO     - Executing program
# 2023-08-15 15:37:52,726 - qm - INFO     - Performing health check.6% (n=100/180)
# 2023-08-15 15:37:52,737 - qm - INFO     - Health check passed
# 2023-08-15 15:37:53,869 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:37:53,996 - qm - INFO     - Executing program
# 2023-08-15 15:37:58,099 - qm - INFO     - Performing health check.1% (n=101/180)
# 2023-08-15 15:37:58,109 - qm - INFO     - Health check passed
# 2023-08-15 15:37:59,156 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:37:59,318 - qm - INFO     - Executing program
# 2023-08-15 15:38:03,336 - qm - INFO     - Performing health check.7% (n=102/180)
# 2023-08-15 15:38:03,347 - qm - INFO     - Health check passed
# 2023-08-15 15:38:04,451 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:38:04,613 - qm - INFO     - Executing program
# 2023-08-15 15:38:08,878 - qm - INFO     - Performing health check.2% (n=103/180)
# 2023-08-15 15:38:08,888 - qm - INFO     - Health check passed
# 2023-08-15 15:38:09,742 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:38:09,880 - qm - INFO     - Executing program
# 2023-08-15 15:38:13,740 - qm - INFO     - Performing health check.8% (n=104/180)
# 2023-08-15 15:38:13,749 - qm - INFO     - Health check passed
# 2023-08-15 15:38:14,491 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:38:14,614 - qm - INFO     - Executing program
# 2023-08-15 15:38:18,782 - qm - INFO     - Performing health check.3% (n=105/180)
# 2023-08-15 15:38:18,792 - qm - INFO     - Health check passed
# 2023-08-15 15:38:19,286 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:38:19,446 - qm - INFO     - Executing program
# 2023-08-15 15:38:23,334 - qm - INFO     - Performing health check.9% (n=106/180)
# 2023-08-15 15:38:23,343 - qm - INFO     - Health check passed
# 2023-08-15 15:38:23,831 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:38:23,974 - qm - INFO     - Executing program
# 2023-08-15 15:38:28,081 - qm - INFO     - Performing health check.4% (n=107/180)
# 2023-08-15 15:38:28,090 - qm - INFO     - Health check passed
# 2023-08-15 15:38:28,964 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:38:29,120 - qm - INFO     - Executing program
# 2023-08-15 15:38:33,149 - qm - INFO     - Performing health check.0% (n=108/180)
# 2023-08-15 15:38:33,159 - qm - INFO     - Health check passed
# 2023-08-15 15:38:34,091 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:38:34,287 - qm - INFO     - Executing program
# 2023-08-15 15:38:38,395 - qm - INFO     - Performing health check.6% (n=109/180)
# 2023-08-15 15:38:38,404 - qm - INFO     - Health check passed
# 2023-08-15 15:38:39,347 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:38:39,491 - qm - INFO     - Executing program
# 2023-08-15 15:38:43,864 - qm - INFO     - Performing health check.1% (n=110/180)
# 2023-08-15 15:38:43,874 - qm - INFO     - Health check passed
# 2023-08-15 15:38:44,724 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:38:44,871 - qm - INFO     - Executing program
# 2023-08-15 15:38:48,982 - qm - INFO     - Performing health check.7% (n=111/180)
# 2023-08-15 15:38:48,989 - qm - INFO     - Health check passed
# 2023-08-15 15:38:49,873 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:38:50,062 - qm - INFO     - Executing program
# 2023-08-15 15:38:54,066 - qm - INFO     - Performing health check.2% (n=112/180)
# 2023-08-15 15:38:54,076 - qm - INFO     - Health check passed
# 2023-08-15 15:38:55,005 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:38:55,154 - qm - INFO     - Executing program
# 2023-08-15 15:38:59,395 - qm - INFO     - Performing health check.8% (n=113/180)
# 2023-08-15 15:38:59,405 - qm - INFO     - Health check passed
# 2023-08-15 15:39:00,282 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:39:00,449 - qm - INFO     - Executing program
# 2023-08-15 15:39:04,376 - qm - INFO     - Performing health check.3% (n=114/180)
# 2023-08-15 15:39:04,386 - qm - INFO     - Health check passed
# 2023-08-15 15:39:05,118 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:39:05,291 - qm - INFO     - Executing program
# 2023-08-15 15:39:09,334 - qm - INFO     - Performing health check.9% (n=115/180)
# 2023-08-15 15:39:09,344 - qm - INFO     - Health check passed
# 2023-08-15 15:39:09,818 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:39:09,967 - qm - INFO     - Executing program
# 2023-08-15 15:39:13,873 - qm - INFO     - Performing health check.4% (n=116/180)
# 2023-08-15 15:39:13,883 - qm - INFO     - Health check passed
# 2023-08-15 15:39:14,430 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:39:14,583 - qm - INFO     - Executing program
# 2023-08-15 15:39:18,653 - qm - INFO     - Performing health check.0% (n=117/180)
# 2023-08-15 15:39:18,663 - qm - INFO     - Health check passed
# 2023-08-15 15:39:19,505 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:39:19,664 - qm - INFO     - Executing program
# 2023-08-15 15:39:23,537 - qm - INFO     - Performing health check.6% (n=118/180)
# 2023-08-15 15:39:23,547 - qm - INFO     - Health check passed
# 2023-08-15 15:39:24,261 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:39:24,396 - qm - INFO     - Executing program
# 2023-08-15 15:39:28,310 - qm - INFO     - Performing health check.1% (n=119/180)
# 2023-08-15 15:39:28,321 - qm - INFO     - Health check passed
# 2023-08-15 15:39:28,792 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:39:28,973 - qm - INFO     - Executing program
# 2023-08-15 15:39:32,879 - qm - INFO     - Performing health check.7% (n=120/180)
# 2023-08-15 15:39:32,889 - qm - INFO     - Health check passed
# 2023-08-15 15:39:33,533 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:39:33,675 - qm - INFO     - Executing program
# 2023-08-15 15:39:37,696 - qm - INFO     - Performing health check.2% (n=121/180)
# 2023-08-15 15:39:37,706 - qm - INFO     - Health check passed
# 2023-08-15 15:39:38,647 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:39:38,807 - qm - INFO     - Executing program
# 2023-08-15 15:39:42,658 - qm - INFO     - Performing health check.8% (n=122/180)
# 2023-08-15 15:39:42,668 - qm - INFO     - Health check passed
# 2023-08-15 15:39:43,401 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:39:43,549 - qm - INFO     - Executing program
# 2023-08-15 15:39:47,567 - qm - INFO     - Performing health check.3% (n=123/180)
# 2023-08-15 15:39:47,577 - qm - INFO     - Health check passed
# 2023-08-15 15:39:48,061 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:39:48,213 - qm - INFO     - Executing program
# 2023-08-15 15:39:52,137 - qm - INFO     - Performing health check.9% (n=124/180)
# 2023-08-15 15:39:52,146 - qm - INFO     - Health check passed
# 2023-08-15 15:39:52,711 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:39:52,850 - qm - INFO     - Executing program
# 2023-08-15 15:39:56,801 - qm - INFO     - Performing health check.4% (n=125/180)
# 2023-08-15 15:39:56,810 - qm - INFO     - Health check passed
# 2023-08-15 15:39:57,793 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:39:57,951 - qm - INFO     - Executing program
# 2023-08-15 15:40:01,885 - qm - INFO     - Performing health check.0% (n=126/180)
# 2023-08-15 15:40:01,894 - qm - INFO     - Health check passed
# 2023-08-15 15:40:02,607 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:40:02,776 - qm - INFO     - Executing program
# 2023-08-15 15:40:06,638 - qm - INFO     - Performing health check.6% (n=127/180)
# 2023-08-15 15:40:06,648 - qm - INFO     - Health check passed
# 2023-08-15 15:40:07,136 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:40:07,275 - qm - INFO     - Executing program
# 2023-08-15 15:40:11,266 - qm - INFO     - Performing health check.1% (n=128/180)
# 2023-08-15 15:40:11,276 - qm - INFO     - Health check passed
# 2023-08-15 15:40:11,927 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:40:12,078 - qm - INFO     - Executing program
# 2023-08-15 15:40:16,071 - qm - INFO     - Performing health check.7% (n=129/180)
# 2023-08-15 15:40:16,081 - qm - INFO     - Health check passed
# 2023-08-15 15:40:17,021 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:40:17,194 - qm - INFO     - Executing program
# 2023-08-15 15:40:21,294 - qm - INFO     - Performing health check.2% (n=130/180)
# 2023-08-15 15:40:21,304 - qm - INFO     - Health check passed
# 2023-08-15 15:40:22,315 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:40:22,484 - qm - INFO     - Executing program
# 2023-08-15 15:40:36,341 - qm - ERROR    - Encountered connection error from QOP)
# Traceback (most recent call last):
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\base_api.py", line 27, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\frontend_api.py", line 79, in get_version
#     response = run_async(self._stub.get_version(Empty(), timeout=self._timeout))
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\utils\async_utils.py", line 37, in run_async
#     return create_future(coroutine).result()  # type: ignore[no-any-return]
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 444, in result
#     return self.__get_result()
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 389, in __get_result
#     raise self._exception
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\grpc\frontend\__init__.py", line 697, in get_version
#     return await self._unary_unary(
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\betterproto\grpc\grpclib_client.py", line 85, in _unary_unary
#     response = await stream.recv_message()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 425, in recv_message
#     await self.recv_initial_metadata()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 371, in recv_initial_metadata
#     self._raise_for_status(headers_map)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 296, in _raise_for_status
#     raise GRPCError(grpc_status,
# grpclib.exceptions.GRPCError: (<Status.UNKNOWN: 2>, "Received :status = '302'", None)
# 2023-08-15 15:40:36,678 - qm - INFO     - Performing health check
# 2023-08-15 15:40:36,690 - qm - INFO     - Health check passed
# 2023-08-15 15:40:37,413 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:40:37,564 - qm - INFO     - Executing program
# 2023-08-15 15:40:51,610 - qm - ERROR    - Encountered connection error from QOP)
# Traceback (most recent call last):
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\base_api.py", line 27, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\frontend_api.py", line 79, in get_version
#     response = run_async(self._stub.get_version(Empty(), timeout=self._timeout))
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\utils\async_utils.py", line 37, in run_async
#     return create_future(coroutine).result()  # type: ignore[no-any-return]
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 444, in result
#     return self.__get_result()
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 389, in __get_result
#     raise self._exception
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\grpc\frontend\__init__.py", line 697, in get_version
#     return await self._unary_unary(
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\betterproto\grpc\grpclib_client.py", line 85, in _unary_unary
#     response = await stream.recv_message()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 425, in recv_message
#     await self.recv_initial_metadata()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 371, in recv_initial_metadata
#     self._raise_for_status(headers_map)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 296, in _raise_for_status
#     raise GRPCError(grpc_status,
# grpclib.exceptions.GRPCError: (<Status.UNKNOWN: 2>, "Received :status = '302'", None)
# 2023-08-15 15:40:51,940 - qm - INFO     - Performing health check
# 2023-08-15 15:40:51,952 - qm - INFO     - Health check passed
# 2023-08-15 15:40:52,459 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:40:52,605 - qm - INFO     - Executing program
# 2023-08-15 15:40:56,575 - qm - INFO     - Performing health check.9% (n=133/180)
# 2023-08-15 15:40:56,584 - qm - INFO     - Health check passed
# 2023-08-15 15:40:57,095 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:40:57,225 - qm - INFO     - Executing program
# 2023-08-15 15:41:11,379 - qm - ERROR    - Encountered connection error from QOP)
# Traceback (most recent call last):
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\base_api.py", line 27, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\frontend_api.py", line 79, in get_version
#     response = run_async(self._stub.get_version(Empty(), timeout=self._timeout))
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\utils\async_utils.py", line 37, in run_async
#     return create_future(coroutine).result()  # type: ignore[no-any-return]
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 444, in result
#     return self.__get_result()
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 389, in __get_result
#     raise self._exception
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\grpc\frontend\__init__.py", line 697, in get_version
#     return await self._unary_unary(
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\betterproto\grpc\grpclib_client.py", line 85, in _unary_unary
#     response = await stream.recv_message()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 425, in recv_message
#     await self.recv_initial_metadata()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 371, in recv_initial_metadata
#     self._raise_for_status(headers_map)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 296, in _raise_for_status
#     raise GRPCError(grpc_status,
# grpclib.exceptions.GRPCError: (<Status.UNKNOWN: 2>, "Received :status = '302'", None)
# 2023-08-15 15:41:11,716 - qm - INFO     - Performing health check
# 2023-08-15 15:41:11,729 - qm - INFO     - Health check passed
# 2023-08-15 15:41:12,557 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:41:12,712 - qm - INFO     - Executing program
# 2023-08-15 15:41:26,645 - qm - ERROR    - Encountered connection error from QOP)
# Traceback (most recent call last):
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\base_api.py", line 27, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\frontend_api.py", line 79, in get_version
#     response = run_async(self._stub.get_version(Empty(), timeout=self._timeout))
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\utils\async_utils.py", line 37, in run_async
#     return create_future(coroutine).result()  # type: ignore[no-any-return]
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 444, in result
#     return self.__get_result()
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 389, in __get_result
#     raise self._exception
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\grpc\frontend\__init__.py", line 697, in get_version
#     return await self._unary_unary(
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\betterproto\grpc\grpclib_client.py", line 85, in _unary_unary
#     response = await stream.recv_message()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 425, in recv_message
#     await self.recv_initial_metadata()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 371, in recv_initial_metadata
#     self._raise_for_status(headers_map)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 296, in _raise_for_status
#     raise GRPCError(grpc_status,
# grpclib.exceptions.GRPCError: (<Status.UNKNOWN: 2>, "Received :status = '302'", None)
# 2023-08-15 15:41:26,994 - qm - INFO     - Performing health check
# 2023-08-15 15:41:27,008 - qm - INFO     - Health check passed
# 2023-08-15 15:41:28,006 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:41:28,145 - qm - INFO     - Executing program
# 2023-08-15 15:41:42,213 - qm - ERROR    - Encountered connection error from QOP)
# Traceback (most recent call last):
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\base_api.py", line 27, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\frontend_api.py", line 79, in get_version
#     response = run_async(self._stub.get_version(Empty(), timeout=self._timeout))
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\utils\async_utils.py", line 37, in run_async
#     return create_future(coroutine).result()  # type: ignore[no-any-return]
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 444, in result
#     return self.__get_result()
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 389, in __get_result
#     raise self._exception
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\grpc\frontend\__init__.py", line 697, in get_version
#     return await self._unary_unary(
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\betterproto\grpc\grpclib_client.py", line 85, in _unary_unary
#     response = await stream.recv_message()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 425, in recv_message
#     await self.recv_initial_metadata()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 371, in recv_initial_metadata
#     self._raise_for_status(headers_map)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 296, in _raise_for_status
#     raise GRPCError(grpc_status,
# grpclib.exceptions.GRPCError: (<Status.UNKNOWN: 2>, "Received :status = '302'", None)
# 2023-08-15 15:41:42,542 - qm - INFO     - Performing health check
# 2023-08-15 15:41:42,557 - qm - INFO     - Health check passed
# 2023-08-15 15:41:43,637 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:41:43,784 - qm - INFO     - Executing program
# 2023-08-15 15:41:57,704 - qm - ERROR    - Encountered connection error from QOP)
# Traceback (most recent call last):
# ...
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\betterproto\grpc\grpclib_client.py", line 85, in _unary_unary
#     response = await stream.recv_message()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 425, in recv_message
#     await self.recv_initial_metadata()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 371, in recv_initial_metadata
#     self._raise_for_status(headers_map)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 296, in _raise_for_status
#     raise GRPCError(grpc_status,
# grpclib.exceptions.GRPCError: (<Status.UNKNOWN: 2>, "Received :status = '302'", None)
# 2023-08-15 15:49:36,249 - qm - INFO     - Performing health check
# 2023-08-15 15:49:36,260 - qm - INFO     - Health check passed
# 2023-08-15 15:49:36,942 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:49:37,080 - qm - INFO     - Executing program
# 2023-08-15 15:49:51,090 - qm - ERROR    - Encountered connection error from QOP)
# Traceback (most recent call last):
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\base_api.py", line 27, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\frontend_api.py", line 79, in get_version
#     response = run_async(self._stub.get_version(Empty(), timeout=self._timeout))
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\utils\async_utils.py", line 37, in run_async
#     return create_future(coroutine).result()  # type: ignore[no-any-return]
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 444, in result
#     return self.__get_result()
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 389, in __get_result
#     raise self._exception
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\grpc\frontend\__init__.py", line 697, in get_version
#     return await self._unary_unary(
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\betterproto\grpc\grpclib_client.py", line 85, in _unary_unary
#     response = await stream.recv_message()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 425, in recv_message
#     await self.recv_initial_metadata()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 371, in recv_initial_metadata
#     self._raise_for_status(headers_map)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 296, in _raise_for_status
#     raise GRPCError(grpc_status,
# grpclib.exceptions.GRPCError: (<Status.UNKNOWN: 2>, "Received :status = '302'", None)
# 2023-08-15 15:49:51,416 - qm - INFO     - Performing health check
# 2023-08-15 15:49:51,430 - qm - INFO     - Health check passed
# 2023-08-15 15:49:52,357 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:49:52,525 - qm - INFO     - Executing program
# 2023-08-15 15:50:06,518 - qm - ERROR    - Encountered connection error from QOP)
# Traceback (most recent call last):
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\base_api.py", line 27, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\frontend_api.py", line 79, in get_version
#     response = run_async(self._stub.get_version(Empty(), timeout=self._timeout))
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\utils\async_utils.py", line 37, in run_async
#     return create_future(coroutine).result()  # type: ignore[no-any-return]
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 444, in result
#     return self.__get_result()
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 389, in __get_result
#     raise self._exception
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\grpc\frontend\__init__.py", line 697, in get_version
#     return await self._unary_unary(
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\betterproto\grpc\grpclib_client.py", line 85, in _unary_unary
#     response = await stream.recv_message()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 425, in recv_message
#     await self.recv_initial_metadata()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 371, in recv_initial_metadata
#     self._raise_for_status(headers_map)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 296, in _raise_for_status
#     raise GRPCError(grpc_status,
# grpclib.exceptions.GRPCError: (<Status.UNKNOWN: 2>, "Received :status = '302'", None)
# 2023-08-15 15:50:06,857 - qm - INFO     - Performing health check
# 2023-08-15 15:50:06,871 - qm - INFO     - Health check passed
# 2023-08-15 15:50:07,547 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:50:07,678 - qm - INFO     - Executing program
# 2023-08-15 15:50:21,693 - qm - ERROR    - Encountered connection error from QOP)
# Traceback (most recent call last):
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\base_api.py", line 27, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\frontend_api.py", line 79, in get_version
#     response = run_async(self._stub.get_version(Empty(), timeout=self._timeout))
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\utils\async_utils.py", line 37, in run_async
#     return create_future(coroutine).result()  # type: ignore[no-any-return]
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 444, in result
#     return self.__get_result()
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 389, in __get_result
#     raise self._exception
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\grpc\frontend\__init__.py", line 697, in get_version
#     return await self._unary_unary(
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\betterproto\grpc\grpclib_client.py", line 85, in _unary_unary
#     response = await stream.recv_message()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 425, in recv_message
#     await self.recv_initial_metadata()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 371, in recv_initial_metadata
#     self._raise_for_status(headers_map)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 296, in _raise_for_status
#     raise GRPCError(grpc_status,
# grpclib.exceptions.GRPCError: (<Status.UNKNOWN: 2>, "Received :status = '302'", None)
# 2023-08-15 15:50:22,051 - qm - INFO     - Performing health check
# 2023-08-15 15:50:22,063 - qm - INFO     - Health check passed
# 2023-08-15 15:50:22,529 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:50:22,664 - qm - INFO     - Executing program
# 2023-08-15 15:50:26,682 - qm - INFO     - Performing health check.2% (n=175/180)
# 2023-08-15 15:50:26,692 - qm - INFO     - Health check passed
# 2023-08-15 15:50:27,191 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:50:27,374 - qm - INFO     - Executing program
# 2023-08-15 15:50:41,266 - qm - ERROR    - Encountered connection error from QOP)
# Traceback (most recent call last):
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\base_api.py", line 27, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\frontend_api.py", line 79, in get_version
#     response = run_async(self._stub.get_version(Empty(), timeout=self._timeout))
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\utils\async_utils.py", line 37, in run_async
#     return create_future(coroutine).result()  # type: ignore[no-any-return]
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 444, in result
#     return self.__get_result()
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 389, in __get_result
#     raise self._exception
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\grpc\frontend\__init__.py", line 697, in get_version
#     return await self._unary_unary(
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\betterproto\grpc\grpclib_client.py", line 85, in _unary_unary
#     response = await stream.recv_message()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 425, in recv_message
#     await self.recv_initial_metadata()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 371, in recv_initial_metadata
#     self._raise_for_status(headers_map)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 296, in _raise_for_status
#     raise GRPCError(grpc_status,
# grpclib.exceptions.GRPCError: (<Status.UNKNOWN: 2>, "Received :status = '302'", None)
# 2023-08-15 15:50:41,606 - qm - INFO     - Performing health check
# 2023-08-15 15:50:41,619 - qm - INFO     - Health check passed
# 2023-08-15 15:50:42,630 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:50:42,779 - qm - INFO     - Executing program
# 2023-08-15 15:50:56,750 - qm - ERROR    - Encountered connection error from QOP)
# Traceback (most recent call last):
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\base_api.py", line 27, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\frontend_api.py", line 79, in get_version
#     response = run_async(self._stub.get_version(Empty(), timeout=self._timeout))
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\utils\async_utils.py", line 37, in run_async
#     return create_future(coroutine).result()  # type: ignore[no-any-return]
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 444, in result
#     return self.__get_result()
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 389, in __get_result
#     raise self._exception
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\grpc\frontend\__init__.py", line 697, in get_version
#     return await self._unary_unary(
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\betterproto\grpc\grpclib_client.py", line 85, in _unary_unary
#     response = await stream.recv_message()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 425, in recv_message
#     await self.recv_initial_metadata()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 371, in recv_initial_metadata
#     self._raise_for_status(headers_map)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 296, in _raise_for_status
#     raise GRPCError(grpc_status,
# grpclib.exceptions.GRPCError: (<Status.UNKNOWN: 2>, "Received :status = '302'", None)
# 2023-08-15 15:50:57,100 - qm - INFO     - Performing health check
# 2023-08-15 15:50:57,112 - qm - INFO     - Health check passed
# 2023-08-15 15:50:58,255 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:50:58,400 - qm - INFO     - Executing program
# 2023-08-15 15:51:12,301 - qm - ERROR    - Encountered connection error from QOP)
# Traceback (most recent call last):
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\base_api.py", line 27, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\frontend_api.py", line 79, in get_version
#     response = run_async(self._stub.get_version(Empty(), timeout=self._timeout))
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\utils\async_utils.py", line 37, in run_async
#     return create_future(coroutine).result()  # type: ignore[no-any-return]
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 444, in result
#     return self.__get_result()
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 389, in __get_result
#     raise self._exception
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\grpc\frontend\__init__.py", line 697, in get_version
#     return await self._unary_unary(
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\betterproto\grpc\grpclib_client.py", line 85, in _unary_unary
#     response = await stream.recv_message()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 425, in recv_message
#     await self.recv_initial_metadata()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 371, in recv_initial_metadata
#     self._raise_for_status(headers_map)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 296, in _raise_for_status
#     raise GRPCError(grpc_status,
# grpclib.exceptions.GRPCError: (<Status.UNKNOWN: 2>, "Received :status = '302'", None)
# 2023-08-15 15:51:12,637 - qm - INFO     - Performing health check
# 2023-08-15 15:51:12,649 - qm - INFO     - Health check passed
# 2023-08-15 15:51:13,366 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:51:13,538 - qm - INFO     - Executing program
# 2023-08-15 15:51:27,509 - qm - ERROR    - Encountered connection error from QOP)
# Traceback (most recent call last):
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\base_api.py", line 27, in wrapped
#     return func(*args, **kwargs)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\api\frontend_api.py", line 79, in get_version
#     response = run_async(self._stub.get_version(Empty(), timeout=self._timeout))
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\utils\async_utils.py", line 37, in run_async
#     return create_future(coroutine).result()  # type: ignore[no-any-return]
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 444, in result
#     return self.__get_result()
#   File "C:\Users\painter\.conda\envs\qm1-env\lib\concurrent\futures\_base.py", line 389, in __get_result
#     raise self._exception
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\qm\grpc\frontend\__init__.py", line 697, in get_version
#     return await self._unary_unary(
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\betterproto\grpc\grpclib_client.py", line 85, in _unary_unary
#     response = await stream.recv_message()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 425, in recv_message
#     await self.recv_initial_metadata()
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 371, in recv_initial_metadata
#     self._raise_for_status(headers_map)
#   File "C:\Users\painter\AppData\Roaming\Python\Python38\site-packages\grpclib\client.py", line 296, in _raise_for_status
#     raise GRPCError(grpc_status,
# grpclib.exceptions.GRPCError: (<Status.UNKNOWN: 2>, "Received :status = '302'", None)
# 2023-08-15 15:51:27,839 - qm - INFO     - Performing health check
# 2023-08-15 15:51:27,852 - qm - INFO     - Health check passed
# 2023-08-15 15:51:28,356 - qm - INFO     - Sending program to QOP for compilation
# 2023-08-15 15:51:28,521 - qm - INFO     - Executing program
# Progress: [##################################################] 100.0% (n=180/180)

# %%
## convert everything to lists so they are easy to parse in Matlab if desired
if isinstance(dcs,np.ndarray) == True:
   dcs1=dcs.tolist()
else:  
    pass
if isinstance(dfs,np.ndarray) == True:
   dfs1=dfs.tolist()
else:  
    pass
if isinstance(I_2D,np.ndarray) == True:
   I1=I_2D.tolist()
else:  
    pass
if isinstance(Q_2D,np.ndarray) == True:
   Q1=Q_2D.tolist()
else:  
    pass

# fq = np.asarray(dfs)
# dc = np.asarray(dcs)
# dataI = np.asarray(I)
# dataQ = np.asarray(Q)
# d1 = pd.DataFrame(fq)
# d2 = pd.DataFrame(dc)
# d3 = pd.DataFrame(dataI)
# d4 = pd.DataFrame(dataQ)
# frames = [d1, d2, d3, d4]
# result = pd.concat(frames)
# # df.index = ['flux', 'freq', 'I', 'Q']
# result.to_csv(os.path.join(tPath, f_name),header=False, index=False)
# open(os.path.join(tPath, j_name), "w").write(open("quam_state.json").read())

data = [('Variable', 'Value'), ('Flux', dcs1), ('Freq', dfs1), ('I', I1), ('Q', Q1)]
df = pd.DataFrame(data,index=None, columns=None)
df.to_csv(os.path.join(tPath, f_name),header=False, index=False)
open(os.path.join(tPath, j_name), "w").write(open("quam_state.json").read())
# Out:
# 3837

# %%
## Fit to a cosine function to optimize readout later

from scipy.optimize import curve_fit

I = np.array(I)
Q = np.array(Q)
dfs = np.array(dfs)
dcs = np.array(dcs)

def cosine_func(x, amplitude, frequency, phase, offset):
        return amplitude * np.cos(2 * np.pi * frequency * x + phase) + offset

Z = I + 1j*Q
mag = np.abs(Z)
mag_transpose = mag.T
minimas = []
for i in range(len(dcs)):
    minimas.append(dfs[np.argmin(mag_transpose[i])])
minimas = np.array(minimas)
initial_guess = [1, 0.5, 0, -1]  # Initial guess for the parameters
fit_params, _ = curve_fit(cosine_func, dcs, minimas/1e6, p0=initial_guess)

# Get the fitted values
amplitude_fit, frequency_fit, phase_fit, offset_fit = fit_params
print('Fit parameters:', fit_params)

# Generate the fitted curve using the fitted parameters
fitted_curve = cosine_func(dcs, amplitude_fit, frequency_fit, phase_fit, offset_fit)
plt.figure()
plt.xlabel("Flux level [V]")
plt.ylabel("Frequency [MHz]")
plt.pcolor(dcs,dfs/u.MHz, np.abs(Z))
plt.plot(dcs, minimas/u.MHz, '.-', color='red')
plt.plot(dcs, fitted_curve, label='Fitted Cosine', color='orange')
plt.colorbar()
# Out:
# Fit parameters: [ 2.36487575  0.84330966  0.00549348 -2.53518794]

# %% [markdown]
# ## fitted in MATLAB to find sweet spot DC flux = 6.4352 mV

# %%
machine._save("quam_state.json", flat_data=False)
